# %%
import pandas as pd
import numpy as np
import lightgbm as lgb 
import xgboost as xgb 
import catboost as cbt 
import numpy as np 
import joblib 
import os 
from sklearn.metrics import mean_absolute_error
import tensorflow as tf
from sklearn.model_selection import GroupKFold
from itertools import combinations
import IPython
import IPython.display
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import gc
import polars as pl
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from catboost import Pool, CatBoostRegressor
from tqdm import tqdm
import tensorflow as tf
from tensorflow import keras
print('Tensorflow version',tf.__version__)
# Out:
# /usr/local/lib/python3.8/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# 2023-11-06 17:26:30.280880: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-06 17:26:31.018935: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Tensorflow version 2.13.1

# %%
NUMS = [ 'imbalance_size',
       'imbalance_buy_sell_flag', 'reference_price', 'matched_size',
       'far_price', 'near_price', 'bid_price', 'bid_size', 'ask_price',
       'ask_size', 'wap','bid_ask_imb_minus', 'imbalance_match_imb_minus']
prices = ['reference_price','far_price', 'near_price', 'ask_price', 'bid_price', 'wap']

gaps = [i for i in range(1, 56)]

# %%
columns_convert = [pl.col(i).cast(pl.Float32) for i in NUMS if i not in ('bid_ask_imb_minus', 'imbalance_match_imb_minus')] 
columns_convert += [(((pl.col('bid_size') - pl.col('ask_size')) ).alias(f'bid_ask_imb_minus')),
                    (((pl.col('imbalance_size') - pl.col('matched_size')) ).alias(f'imbalance_match_imb_minus')),
                   
                   ]
columns = [] 

for i,a in enumerate(prices):
    for j,b in enumerate(prices):
        if i>j:
            columns.append( (((pl.col(a) - pl.col(b))/(pl.col(a)+pl.col(b)) ).alias(f'{a}_{b}_imb')) )
            columns.append( (((pl.col(a) - pl.col(b)) ).alias(f'{a}_{b}_imb_minus')) )
            
columns_part2 = [
    
    
    #**[pl.col("imbalance_size").shift(i).fill_null(0).clip(-1e9, 1e9).over(["stock_id", "date_id"]).alias(f"imbalance_size_{i}") for i in range(1, 6)],
    
    
#     (( pl.col("imbalance_size").shift(1)).fill_null(0).clip(-1e9, 1e9).over(["stock_id", "date_id"]).alias("imbalance_size_0")),
#     (( pl.col("imbalance_size").shift(2)).fill_null(0).clip(-1e9, 1e9).over(["stock_id", "date_id"]).alias("imbalance_size_1")),
#     (( pl.col("imbalance_size").shift(3)).fill_null(0).clip(-1e9, 1e9).over(["stock_id", "date_id"]).alias("imbalance_size_2")),
#     (( pl.col("imbalance_size").shift(4)).fill_null(0).clip(-1e9, 1e9).over(["stock_id", "date_id"]).alias("imbalance_size_3")),
#     (( pl.col("imbalance_size").shift(5)).fill_null(0).clip(-1e9, 1e9).over(["stock_id", "date_id"]).alias("imbalance_size_4")),
#     (( pl.col("imbalance_size").shift(6)).fill_null(0).clip(-1e9, 1e9).over(["stock_id", "date_id"]).alias("imbalance_size_5")),
    
    
    ((pl.col("imbalance_size") - pl.col("imbalance_size").shift(1)).fill_null(0).clip(-1e9, 1e9).over(["stock_id", "date_id"]).alias("imbalance_size_diff_0")),
    ((pl.col("imbalance_size") - pl.col("imbalance_size").shift(2)).fill_null(0).clip(-1e9, 1e9).over(["stock_id", "date_id"]).alias("imbalance_size_diff_1")),
    ((pl.col("imbalance_size") - pl.col("imbalance_size").shift(3)).fill_null(0).clip(-1e9, 1e9).over(["stock_id", "date_id"]).alias("imbalance_size_diff_2")),
    ((pl.col("imbalance_size") - pl.col("imbalance_size").shift(4)).fill_null(0).clip(-1e9, 1e9).over(["stock_id", "date_id"]).alias("imbalance_size_diff_3")),
    ((pl.col("imbalance_size") - pl.col("imbalance_size").shift(5)).fill_null(0).clip(-1e9, 1e9).over(["stock_id", "date_id"]).alias("imbalance_size_diff_4")),
    ((pl.col("imbalance_size") - pl.col("imbalance_size").shift(6)).fill_null(0).clip(-1e9, 1e9).over(["stock_id", "date_id"]).alias("imbalance_size_diff_5")),
    
    
    ((pl.col("matched_size") - pl.col("matched_size").shift(1)).fill_null(0).clip(-1e9, 1e9).over(["stock_id", "date_id"]).alias("matched_size_diff_0")),
    ((pl.col("matched_size") - pl.col("matched_size").shift(2)).fill_null(0).clip(-1e9, 1e9).over(["stock_id", "date_id"]).alias("matched_size_diff_1")),
    ((pl.col("matched_size") - pl.col("matched_size").shift(3)).fill_null(0).clip(-1e9, 1e9).over(["stock_id", "date_id"]).alias("matched_size_diff_2")),
    ((pl.col("matched_size") - pl.col("matched_size").shift(4)).fill_null(0).clip(-1e9, 1e9).over(["stock_id", "date_id"]).alias("matched_size_diff_3")),
    ((pl.col("matched_size") - pl.col("matched_size").shift(5)).fill_null(0).clip(-1e9, 1e9).over(["stock_id", "date_id"]).alias("matched_size_diff_4")),
    ((pl.col("matched_size") - pl.col("matched_size").shift(6)).fill_null(0).clip(-1e9, 1e9).over(["stock_id", "date_id"]).alias("matched_size_diff_5")),
    
    ((pl.col("bid_size") - pl.col("bid_size").shift(1)).fill_null(0).clip(-1e9, 1e9).over(["stock_id", "date_id"]).alias("bid_size_diff_0")),
    ((pl.col("bid_size") - pl.col("bid_size").shift(2)).fill_null(0).clip(-1e9, 1e9).over(["stock_id", "date_id"]).alias("bid_size_diff_1")),
    ((pl.col("bid_size") - pl.col("bid_size").shift(3)).fill_null(0).clip(-1e9, 1e9).over(["stock_id", "date_id"]).alias("bid_size_diff_2")),
    ((pl.col("bid_size") - pl.col("bid_size").shift(4)).fill_null(0).clip(-1e9, 1e9).over(["stock_id", "date_id"]).alias("bid_size_diff_3")),
    ((pl.col("bid_size") - pl.col("bid_size").shift(5)).fill_null(0).clip(-1e9, 1e9).over(["stock_id", "date_id"]).alias("bid_size_diff_4")),
    ((pl.col("bid_size") - pl.col("bid_size").shift(6)).fill_null(0).clip(-1e9, 1e9).over(["stock_id", "date_id"]).alias("bid_size_diff_5")),

    ((pl.col("ask_size") - pl.col("ask_size").shift(1)).fill_null(0).clip(-1e9, 1e9).over(["stock_id", "date_id"]).alias("ask_size_diff_0")),
    ((pl.col("ask_size") - pl.col("ask_size").shift(2)).fill_null(0).clip(-1e9, 1e9).over(["stock_id", "date_id"]).alias("ask_size_diff_1")),
    ((pl.col("ask_size") - pl.col("ask_size").shift(3)).fill_null(0).clip(-1e9, 1e9).over(["stock_id", "date_id"]).alias("ask_size_diff_2")),
    ((pl.col("ask_size") - pl.col("ask_size").shift(4)).fill_null(0).clip(-1e9, 1e9).over(["stock_id", "date_id"]).alias("ask_size_diff_3")),
    ((pl.col("ask_size") - pl.col("ask_size").shift(5)).fill_null(0).clip(-1e9, 1e9).over(["stock_id", "date_id"]).alias("ask_size_diff_4")),
    ((pl.col("ask_size") - pl.col("ask_size").shift(6)).fill_null(0).clip(-1e9, 1e9).over(["stock_id", "date_id"]).alias("ask_size_diff_5")),
    
    ((pl.col("bid_ask_imb_minus") - pl.col("bid_ask_imb_minus").shift(1)).fill_null(0).clip(-1e9, 1e9).over(["stock_id", "date_id"]).alias("bid_ask_imb_minus_diff_0")),
    ((pl.col("bid_ask_imb_minus") - pl.col("bid_ask_imb_minus").shift(2)).fill_null(0).clip(-1e9, 1e9).over(["stock_id", "date_id"]).alias("bid_ask_imb_minus_diff_1")),
    ((pl.col("bid_ask_imb_minus") - pl.col("bid_ask_imb_minus").shift(3)).fill_null(0).clip(-1e9, 1e9).over(["stock_id", "date_id"]).alias("bid_ask_imb_minus_diff_2")),
    ((pl.col("bid_ask_imb_minus") - pl.col("bid_ask_imb_minus").shift(4)).fill_null(0).clip(-1e9, 1e9).over(["stock_id", "date_id"]).alias("bid_ask_imb_minus_diff_3")),
    ((pl.col("bid_ask_imb_minus") - pl.col("bid_ask_imb_minus").shift(5)).fill_null(0).clip(-1e9, 1e9).over(["stock_id", "date_id"]).alias("bid_ask_imb_minus_diff_4")),
    ((pl.col("bid_ask_imb_minus") - pl.col("bid_ask_imb_minus").shift(6)).fill_null(0).clip(-1e9, 1e9).over(["stock_id", "date_id"]).alias("bid_ask_imb_minus_diff_5")),
    
    ((pl.col("imbalance_match_imb_minus") - pl.col("imbalance_match_imb_minus").shift(1)).fill_null(0).clip(-1e9, 1e9).over(["stock_id", "date_id"]).alias("imbalance_match_imb_minus_diff_0")),
    ((pl.col("imbalance_match_imb_minus") - pl.col("imbalance_match_imb_minus").shift(2)).fill_null(0).clip(-1e9, 1e9).over(["stock_id", "date_id"]).alias("imbalance_match_imb_minus_diff_1")),
    ((pl.col("imbalance_match_imb_minus") - pl.col("imbalance_match_imb_minus").shift(3)).fill_null(0).clip(-1e9, 1e9).over(["stock_id", "date_id"]).alias("imbalance_match_imb_minus_diff_2")),
    ((pl.col("imbalance_match_imb_minus") - pl.col("imbalance_match_imb_minus").shift(4)).fill_null(0).clip(-1e9, 1e9).over(["stock_id", "date_id"]).alias("imbalance_match_imb_minus_diff_3")),
    ((pl.col("imbalance_match_imb_minus") - pl.col("imbalance_match_imb_minus").shift(5)).fill_null(0).clip(-1e9, 1e9).over(["stock_id", "date_id"]).alias("imbalance_match_imb_minus_diff_4")),
    ((pl.col("imbalance_match_imb_minus") - pl.col("imbalance_match_imb_minus").shift(6)).fill_null(0).clip(-1e9, 1e9).over(["stock_id", "date_id"]).alias("imbalance_match_imb_minus_diff_5")),
    
    ( (  (pl.col("matched_size") - pl.col("imbalance_size")) / (pl.col("matched_size") + pl.col("imbalance_size"))  ).alias("matched_imblance_diff_0") ),
    ( (  (pl.col("matched_size") - pl.col("imbalance_size"))   ).alias("matched_imblance_diff_1") ),
    # bid_size-ask_size
    ( (pl.col("bid_size") - pl.col("ask_size")).alias("bid_ask_diff_0") ),
    ( (  (pl.col("bid_size") - pl.col("ask_size")) / (pl.col("bid_size") + pl.col("ask_size"))  ).alias("bid_ask_diff_1") ),
]


mins = 60
day = 1
year = (365.2425)*day

columns_part3 = [

    # ( np.sin((pl.col("date_id") + 1) * (2 * np.pi / day)).alias("day_sin") ),
    # ( np.cos((pl.col("date_id") + 1) * (2 * np.pi / day)).alias("day_cos") ),
#     ( np.sin((pl.col("date_id") + 1) * (2 * np.pi / year)).alias("year_sin") ),
#     ( np.cos((pl.col("date_id") + 1) * (2 * np.pi / year)).alias("year_cos") ),
    
#     ( np.sin((pl.col("seconds_in_bucket")) * (2 * np.pi / mins)).alias("min_sin") ),
#     ( np.cos((pl.col("seconds_in_bucket") ) * (2 * np.pi / mins)).alias("min_cos") ),
    
    ( np.sin((pl.col("seconds_in_bucket")) * (2 * np.pi / 1)).alias("second_sin") ),
    ( np.cos((pl.col("seconds_in_bucket") ) * (2 * np.pi / 1)).alias("second_cos") ),
]

columns_part4 = []
for num in NUMS:
    for gap in gaps:
        columns_part4.append(
            
        pl.col(num).shift(gap).fill_null(0).clip(-1e9, 1e9).over(["stock_id", "date_id"]).alias(f"{num}_gap_{gap}")
        
        )


columns += columns_part2 + columns_part4 + columns_part3

# %%
df = (pl.read_csv("train.csv")
      .with_columns(columns_convert)
      .with_columns(columns)
      .drop(['row_id', 'time_id'])
     )

df = df.filter(pl.col('date_id')> 300)

# %%
NUMS += [i for i in df.columns if i not in ['stock_id', 'date_id', 'seconds_in_bucket'] and i not in NUMS]
NUMS
# Out:
# ['imbalance_size',
#  'imbalance_buy_sell_flag',
#  'reference_price',
#  'matched_size',
#  'far_price',
#  'near_price',
#  'bid_price',
#  'bid_size',
#  'ask_price',
#  'ask_size',
#  'wap',
#  'bid_ask_imb_minus',
#  'imbalance_match_imb_minus',
#  'target',
#  'far_price_reference_price_imb',
#  'far_price_reference_price_imb_minus',
#  'near_price_reference_price_imb',
#  'near_price_reference_price_imb_minus',
#  'near_price_far_price_imb',
#  'near_price_far_price_imb_minus',
#  'ask_price_reference_price_imb',
#  'ask_price_reference_price_imb_minus',
#  'ask_price_far_price_imb',
#  'ask_price_far_price_imb_minus',
#  'ask_price_near_price_imb',
#  'ask_price_near_price_imb_minus',
#  'bid_price_reference_price_imb',
#  'bid_price_reference_price_imb_minus',
#  'bid_price_far_price_imb',
#  'bid_price_far_price_imb_minus',
#  'bid_price_near_price_imb',
#  'bid_price_near_price_imb_minus',
#  'bid_price_ask_price_imb',
#  'bid_price_ask_price_imb_minus',
#  'wap_reference_price_imb',
#  'wap_reference_price_imb_minus',
#  'wap_far_price_imb',
#  'wap_far_price_imb_minus',
#  'wap_near_price_imb',
#  'wap_near_price_imb_minus',
#  'wap_ask_price_imb',
#  'wap_ask_price_imb_minus',
#  'wap_bid_price_imb',
#  'wap_bid_price_imb_minus',
#  'imbalance_size_diff_0',
#  'imbalance_size_diff_1',
#  'imbalance_size_diff_2',
#  'imbalance_size_diff_3',
#  'imbalance_size_diff_4',
#  'imbalance_size_diff_5',
#  'matched_size_diff_0',
#  'matched_size_diff_1',
#  'matched_size_diff_2',
#  'matched_size_diff_3',
#  'matched_size_diff_4',
#  'matched_size_diff_5',
#  'bid_size_diff_0',
#  'bid_size_diff_1',
#  'bid_size_diff_2',
#  'bid_size_diff_3',
#  'bid_size_diff_4',
#  'bid_size_diff_5',
#  'ask_size_diff_0',
#  'ask_size_diff_1',
#  'ask_size_diff_2',
#  'ask_size_diff_3',
#  'ask_size_diff_4',
#  'ask_size_diff_5',
#  'bid_ask_imb_minus_diff_0',
#  'bid_ask_imb_minus_diff_1',
#  'bid_ask_imb_minus_diff_2',
#  'bid_ask_imb_minus_diff_3',
#  'bid_ask_imb_minus_diff_4',
#  'bid_ask_imb_minus_diff_5',
#  'imbalance_match_imb_minus_diff_0',
#  'imbalance_match_imb_minus_diff_1',
#  'imbalance_match_imb_minus_diff_2',
#  'imbalance_match_imb_minus_diff_3',
#  'imbalance_match_imb_minus_diff_4',
#  'imbalance_match_imb_minus_diff_5',
#  'matched_imblance_diff_0',
#  'matched_imblance_diff_1',
#  'bid_ask_diff_0',
#  'bid_ask_diff_1',
#  'imbalance_size_gap_1',
#  'imbalance_size_gap_2',
#  'imbalance_size_gap_3',
#  'imbalance_size_gap_4',
#  'imbalance_size_gap_5',
#  'imbalance_size_gap_6',
#  'imbalance_size_gap_7',
#  'imbalance_size_gap_8',
#  'imbalance_size_gap_9',
#  'imbalance_size_gap_10',
#  'imbalance_size_gap_11',
#  'imbalance_size_gap_12',
#  'imbalance_size_gap_13',
#  'imbalance_size_gap_14',
#  'imbalance_size_gap_15',
#  'imbalance_size_gap_16',
#  'imbalance_size_gap_17',
#  'imbalance_size_gap_18',
#  'imbalance_size_gap_19',
#  'imbalance_size_gap_20',
#  'imbalance_size_gap_21',
#  'imbalance_size_gap_22',
#  'imbalance_size_gap_23',
#  'imbalance_size_gap_24',
#  'imbalance_size_gap_25',
#  'imbalance_size_gap_26',
#  'imbalance_size_gap_27',
#  'imbalance_size_gap_28',
#  'imbalance_size_gap_29',
#  'imbalance_size_gap_30',
#  'imbalance_size_gap_31',
#  'imbalance_size_gap_32',
#  'imbalance_size_gap_33',
#  'imbalance_size_gap_34',
#  'imbalance_size_gap_35',
#  'imbalance_size_gap_36',
#  'imbalance_size_gap_37',
#  'imbalance_size_gap_38',
#  'imbalance_size_gap_39',
#  'imbalance_size_gap_40',
#  'imbalance_size_gap_41',
#  'imbalance_size_gap_42',
#  'imbalance_size_gap_43',
#  'imbalance_size_gap_44',
#  'imbalance_size_gap_45',
#  'imbalance_size_gap_46',
#  'imbalance_size_gap_47',
#  'imbalance_size_gap_48',
#  'imbalance_size_gap_49',
#  'imbalance_size_gap_50',
#  'imbalance_size_gap_51',
#  'imbalance_size_gap_52',
#  'imbalance_size_gap_53',
#  'imbalance_size_gap_54',
#  'imbalance_size_gap_55',
#  'imbalance_buy_sell_flag_gap_1',
#  'imbalance_buy_sell_flag_gap_2',
#  'imbalance_buy_sell_flag_gap_3',
#  'imbalance_buy_sell_flag_gap_4',
#  'imbalance_buy_sell_flag_gap_5',
#  'imbalance_buy_sell_flag_gap_6',
#  'imbalance_buy_sell_flag_gap_7',
#  'imbalance_buy_sell_flag_gap_8',
#  'imbalance_buy_sell_flag_gap_9',
#  'imbalance_buy_sell_flag_gap_10',
#  'imbalance_buy_sell_flag_gap_11',
#  'imbalance_buy_sell_flag_gap_12',
#  'imbalance_buy_sell_flag_gap_13',
#  'imbalance_buy_sell_flag_gap_14',
#  'imbalance_buy_sell_flag_gap_15',
#  'imbalance_buy_sell_flag_gap_16',
#  'imbalance_buy_sell_flag_gap_17',
#  'imbalance_buy_sell_flag_gap_18',
#  'imbalance_buy_sell_flag_gap_19',
#  'imbalance_buy_sell_flag_gap_20',
#  'imbalance_buy_sell_flag_gap_21',
#  'imbalance_buy_sell_flag_gap_22',
#  'imbalance_buy_sell_flag_gap_23',
#  'imbalance_buy_sell_flag_gap_24',
#  'imbalance_buy_sell_flag_gap_25',
#  'imbalance_buy_sell_flag_gap_26',
#  'imbalance_buy_sell_flag_gap_27',
#  'imbalance_buy_sell_flag_gap_28',
#  'imbalance_buy_sell_flag_gap_29',
#  'imbalance_buy_sell_flag_gap_30',
#  'imbalance_buy_sell_flag_gap_31',
#  'imbalance_buy_sell_flag_gap_32',
#  'imbalance_buy_sell_flag_gap_33',
#  'imbalance_buy_sell_flag_gap_34',
#  'imbalance_buy_sell_flag_gap_35',
#  'imbalance_buy_sell_flag_gap_36',
#  'imbalance_buy_sell_flag_gap_37',
#  'imbalance_buy_sell_flag_gap_38',
#  'imbalance_buy_sell_flag_gap_39',
#  'imbalance_buy_sell_flag_gap_40',
#  'imbalance_buy_sell_flag_gap_41',
#  'imbalance_buy_sell_flag_gap_42',
#  'imbalance_buy_sell_flag_gap_43',
#  'imbalance_buy_sell_flag_gap_44',
#  'imbalance_buy_sell_flag_gap_45',
#  'imbalance_buy_sell_flag_gap_46',
#  'imbalance_buy_sell_flag_gap_47',
#  'imbalance_buy_sell_flag_gap_48',
#  'imbalance_buy_sell_flag_gap_49',
#  'imbalance_buy_sell_flag_gap_50',
#  'imbalance_buy_sell_flag_gap_51',
#  'imbalance_buy_sell_flag_gap_52',
#  'imbalance_buy_sell_flag_gap_53',
#  'imbalance_buy_sell_flag_gap_54',
#  'imbalance_buy_sell_flag_gap_55',
#  'reference_price_gap_1',
#  'reference_price_gap_2',
#  'reference_price_gap_3',
#  'reference_price_gap_4',
#  'reference_price_gap_5',
#  'reference_price_gap_6',
#  'reference_price_gap_7',
#  'reference_price_gap_8',
#  'reference_price_gap_9',
#  'reference_price_gap_10',
#  'reference_price_gap_11',
#  'reference_price_gap_12',
#  'reference_price_gap_13',
#  'reference_price_gap_14',
#  'reference_price_gap_15',
#  'reference_price_gap_16',
#  'reference_price_gap_17',
#  'reference_price_gap_18',
#  'reference_price_gap_19',
#  'reference_price_gap_20',
#  'reference_price_gap_21',
#  'reference_price_gap_22',
#  'reference_price_gap_23',
#  'reference_price_gap_24',
#  'reference_price_gap_25',
#  'reference_price_gap_26',
#  'reference_price_gap_27',
#  'reference_price_gap_28',
#  'reference_price_gap_29',
#  'reference_price_gap_30',
#  'reference_price_gap_31',
#  'reference_price_gap_32',
#  'reference_price_gap_33',
#  'reference_price_gap_34',
#  'reference_price_gap_35',
#  'reference_price_gap_36',
#  'reference_price_gap_37',
#  'reference_price_gap_38',
#  'reference_price_gap_39',
#  'reference_price_gap_40',
#  'reference_price_gap_41',
#  'reference_price_gap_42',
#  'reference_price_gap_43',
#  'reference_price_gap_44',
#  'reference_price_gap_45',
#  'reference_price_gap_46',
#  'reference_price_gap_47',
#  'reference_price_gap_48',
#  'reference_price_gap_49',
#  'reference_price_gap_50',
#  'reference_price_gap_51',
#  'reference_price_gap_52',
#  'reference_price_gap_53',
#  'reference_price_gap_54',
#  'reference_price_gap_55',
#  'matched_size_gap_1',
#  'matched_size_gap_2',
#  'matched_size_gap_3',
#  'matched_size_gap_4',
#  'matched_size_gap_5',
#  'matched_size_gap_6',
#  'matched_size_gap_7',
#  'matched_size_gap_8',
#  'matched_size_gap_9',
#  'matched_size_gap_10',
#  'matched_size_gap_11',
#  'matched_size_gap_12',
#  'matched_size_gap_13',
#  'matched_size_gap_14',
#  'matched_size_gap_15',
#  'matched_size_gap_16',
#  'matched_size_gap_17',
#  'matched_size_gap_18',
#  'matched_size_gap_19',
#  'matched_size_gap_20',
#  'matched_size_gap_21',
#  'matched_size_gap_22',
#  'matched_size_gap_23',
#  'matched_size_gap_24',
#  'matched_size_gap_25',
#  'matched_size_gap_26',
#  'matched_size_gap_27',
#  'matched_size_gap_28',
#  'matched_size_gap_29',
#  'matched_size_gap_30',
#  'matched_size_gap_31',
#  'matched_size_gap_32',
#  'matched_size_gap_33',
#  'matched_size_gap_34',
#  'matched_size_gap_35',
#  'matched_size_gap_36',
#  'matched_size_gap_37',
#  'matched_size_gap_38',
#  'matched_size_gap_39',
#  'matched_size_gap_40',
#  'matched_size_gap_41',
#  'matched_size_gap_42',
#  'matched_size_gap_43',
#  'matched_size_gap_44',
#  'matched_size_gap_45',
#  'matched_size_gap_46',
#  'matched_size_gap_47',
#  'matched_size_gap_48',
#  'matched_size_gap_49',
#  'matched_size_gap_50',
#  'matched_size_gap_51',
#  'matched_size_gap_52',
#  'matched_size_gap_53',
#  'matched_size_gap_54',
#  'matched_size_gap_55',
#  'far_price_gap_1',
#  'far_price_gap_2',
#  'far_price_gap_3',
#  'far_price_gap_4',
#  'far_price_gap_5',
#  'far_price_gap_6',
#  'far_price_gap_7',
#  'far_price_gap_8',
#  'far_price_gap_9',
#  'far_price_gap_10',
#  'far_price_gap_11',
#  'far_price_gap_12',
#  'far_price_gap_13',
#  'far_price_gap_14',
#  'far_price_gap_15',
#  'far_price_gap_16',
#  'far_price_gap_17',
#  'far_price_gap_18',
#  'far_price_gap_19',
#  'far_price_gap_20',
#  'far_price_gap_21',
#  'far_price_gap_22',
#  'far_price_gap_23',
#  'far_price_gap_24',
#  'far_price_gap_25',
#  'far_price_gap_26',
#  'far_price_gap_27',
#  'far_price_gap_28',
#  'far_price_gap_29',
#  'far_price_gap_30',
#  'far_price_gap_31',
#  'far_price_gap_32',
#  'far_price_gap_33',
#  'far_price_gap_34',
#  'far_price_gap_35',
#  'far_price_gap_36',
#  'far_price_gap_37',
#  'far_price_gap_38',
#  'far_price_gap_39',
#  'far_price_gap_40',
#  'far_price_gap_41',
#  'far_price_gap_42',
#  'far_price_gap_43',
#  'far_price_gap_44',
#  'far_price_gap_45',
#  'far_price_gap_46',
#  'far_price_gap_47',
#  'far_price_gap_48',
#  'far_price_gap_49',
#  'far_price_gap_50',
#  'far_price_gap_51',
#  'far_price_gap_52',
#  'far_price_gap_53',
#  'far_price_gap_54',
#  'far_price_gap_55',
#  'near_price_gap_1',
#  'near_price_gap_2',
#  'near_price_gap_3',
#  'near_price_gap_4',
#  'near_price_gap_5',
#  'near_price_gap_6',
#  'near_price_gap_7',
#  'near_price_gap_8',
#  'near_price_gap_9',
#  'near_price_gap_10',
#  'near_price_gap_11',
#  'near_price_gap_12',
#  'near_price_gap_13',
#  'near_price_gap_14',
#  'near_price_gap_15',
#  'near_price_gap_16',
#  'near_price_gap_17',
#  'near_price_gap_18',
#  'near_price_gap_19',
#  'near_price_gap_20',
#  'near_price_gap_21',
#  'near_price_gap_22',
#  'near_price_gap_23',
#  'near_price_gap_24',
#  'near_price_gap_25',
#  'near_price_gap_26',
#  'near_price_gap_27',
#  'near_price_gap_28',
#  'near_price_gap_29',
#  'near_price_gap_30',
#  'near_price_gap_31',
#  'near_price_gap_32',
#  'near_price_gap_33',
#  'near_price_gap_34',
#  'near_price_gap_35',
#  'near_price_gap_36',
#  'near_price_gap_37',
#  'near_price_gap_38',
#  'near_price_gap_39',
#  'near_price_gap_40',
#  'near_price_gap_41',
#  'near_price_gap_42',
#  'near_price_gap_43',
#  'near_price_gap_44',
#  'near_price_gap_45',
#  'near_price_gap_46',
#  'near_price_gap_47',
#  'near_price_gap_48',
#  'near_price_gap_49',
#  'near_price_gap_50',
#  'near_price_gap_51',
#  'near_price_gap_52',
#  'near_price_gap_53',
#  'near_price_gap_54',
#  'near_price_gap_55',
#  'bid_price_gap_1',
#  'bid_price_gap_2',
#  'bid_price_gap_3',
#  'bid_price_gap_4',
#  'bid_price_gap_5',
#  'bid_price_gap_6',
#  'bid_price_gap_7',
#  'bid_price_gap_8',
#  'bid_price_gap_9',
#  'bid_price_gap_10',
#  'bid_price_gap_11',
#  'bid_price_gap_12',
#  'bid_price_gap_13',
#  'bid_price_gap_14',
#  'bid_price_gap_15',
#  'bid_price_gap_16',
#  'bid_price_gap_17',
#  'bid_price_gap_18',
#  'bid_price_gap_19',
#  'bid_price_gap_20',
#  'bid_price_gap_21',
#  'bid_price_gap_22',
#  'bid_price_gap_23',
#  'bid_price_gap_24',
#  'bid_price_gap_25',
#  'bid_price_gap_26',
#  'bid_price_gap_27',
#  'bid_price_gap_28',
#  'bid_price_gap_29',
#  'bid_price_gap_30',
#  'bid_price_gap_31',
#  'bid_price_gap_32',
#  'bid_price_gap_33',
#  'bid_price_gap_34',
#  'bid_price_gap_35',
#  'bid_price_gap_36',
#  'bid_price_gap_37',
#  'bid_price_gap_38',
#  'bid_price_gap_39',
#  'bid_price_gap_40',
#  'bid_price_gap_41',
#  'bid_price_gap_42',
#  'bid_price_gap_43',
#  'bid_price_gap_44',
#  'bid_price_gap_45',
#  'bid_price_gap_46',
#  'bid_price_gap_47',
#  'bid_price_gap_48',
#  'bid_price_gap_49',
#  'bid_price_gap_50',
#  'bid_price_gap_51',
#  'bid_price_gap_52',
#  'bid_price_gap_53',
#  'bid_price_gap_54',
#  'bid_price_gap_55',
#  'bid_size_gap_1',
#  'bid_size_gap_2',
#  'bid_size_gap_3',
#  'bid_size_gap_4',
#  'bid_size_gap_5',
#  'bid_size_gap_6',
#  'bid_size_gap_7',
#  'bid_size_gap_8',
#  'bid_size_gap_9',
#  'bid_size_gap_10',
#  'bid_size_gap_11',
#  'bid_size_gap_12',
#  'bid_size_gap_13',
#  'bid_size_gap_14',
#  'bid_size_gap_15',
#  'bid_size_gap_16',
#  'bid_size_gap_17',
#  'bid_size_gap_18',
#  'bid_size_gap_19',
#  'bid_size_gap_20',
#  'bid_size_gap_21',
#  'bid_size_gap_22',
#  'bid_size_gap_23',
#  'bid_size_gap_24',
#  'bid_size_gap_25',
#  'bid_size_gap_26',
#  'bid_size_gap_27',
#  'bid_size_gap_28',
#  'bid_size_gap_29',
#  'bid_size_gap_30',
#  'bid_size_gap_31',
#  'bid_size_gap_32',
#  'bid_size_gap_33',
#  'bid_size_gap_34',
#  'bid_size_gap_35',
#  'bid_size_gap_36',
#  'bid_size_gap_37',
#  'bid_size_gap_38',
#  'bid_size_gap_39',
#  'bid_size_gap_40',
#  'bid_size_gap_41',
#  'bid_size_gap_42',
#  'bid_size_gap_43',
#  'bid_size_gap_44',
#  'bid_size_gap_45',
#  'bid_size_gap_46',
#  'bid_size_gap_47',
#  'bid_size_gap_48',
#  'bid_size_gap_49',
#  'bid_size_gap_50',
#  'bid_size_gap_51',
#  'bid_size_gap_52',
#  'bid_size_gap_53',
#  'bid_size_gap_54',
#  'bid_size_gap_55',
#  'ask_price_gap_1',
#  'ask_price_gap_2',
#  'ask_price_gap_3',
#  'ask_price_gap_4',
#  'ask_price_gap_5',
#  'ask_price_gap_6',
#  'ask_price_gap_7',
#  'ask_price_gap_8',
#  'ask_price_gap_9',
#  'ask_price_gap_10',
#  'ask_price_gap_11',
#  'ask_price_gap_12',
#  'ask_price_gap_13',
#  'ask_price_gap_14',
#  'ask_price_gap_15',
#  'ask_price_gap_16',
#  'ask_price_gap_17',
#  'ask_price_gap_18',
#  'ask_price_gap_19',
#  'ask_price_gap_20',
#  'ask_price_gap_21',
#  'ask_price_gap_22',
#  'ask_price_gap_23',
#  'ask_price_gap_24',
#  'ask_price_gap_25',
#  'ask_price_gap_26',
#  'ask_price_gap_27',
#  'ask_price_gap_28',
#  'ask_price_gap_29',
#  'ask_price_gap_30',
#  'ask_price_gap_31',
#  'ask_price_gap_32',
#  'ask_price_gap_33',
#  'ask_price_gap_34',
#  'ask_price_gap_35',
#  'ask_price_gap_36',
#  'ask_price_gap_37',
#  'ask_price_gap_38',
#  'ask_price_gap_39',
#  'ask_price_gap_40',
#  'ask_price_gap_41',
#  'ask_price_gap_42',
#  'ask_price_gap_43',
#  'ask_price_gap_44',
#  'ask_price_gap_45',
#  'ask_price_gap_46',
#  'ask_price_gap_47',
#  'ask_price_gap_48',
#  'ask_price_gap_49',
#  'ask_price_gap_50',
#  'ask_price_gap_51',
#  'ask_price_gap_52',
#  'ask_price_gap_53',
#  'ask_price_gap_54',
#  'ask_price_gap_55',
#  'ask_size_gap_1',
#  'ask_size_gap_2',
#  'ask_size_gap_3',
#  'ask_size_gap_4',
#  'ask_size_gap_5',
#  'ask_size_gap_6',
#  'ask_size_gap_7',
#  'ask_size_gap_8',
#  'ask_size_gap_9',
#  'ask_size_gap_10',
#  'ask_size_gap_11',
#  'ask_size_gap_12',
#  'ask_size_gap_13',
#  'ask_size_gap_14',
#  'ask_size_gap_15',
#  'ask_size_gap_16',
#  'ask_size_gap_17',
#  'ask_size_gap_18',
#  'ask_size_gap_19',
#  'ask_size_gap_20',
#  'ask_size_gap_21',
#  'ask_size_gap_22',
#  'ask_size_gap_23',
#  'ask_size_gap_24',
#  'ask_size_gap_25',
#  'ask_size_gap_26',
#  'ask_size_gap_27',
#  'ask_size_gap_28',
#  'ask_size_gap_29',
#  'ask_size_gap_30',
#  'ask_size_gap_31',
#  'ask_size_gap_32',
#  'ask_size_gap_33',
#  'ask_size_gap_34',
#  'ask_size_gap_35',
#  'ask_size_gap_36',
#  'ask_size_gap_37',
#  'ask_size_gap_38',
#  'ask_size_gap_39',
#  'ask_size_gap_40',
#  'ask_size_gap_41',
#  'ask_size_gap_42',
#  'ask_size_gap_43',
#  'ask_size_gap_44',
#  'ask_size_gap_45',
#  'ask_size_gap_46',
#  'ask_size_gap_47',
#  'ask_size_gap_48',
#  'ask_size_gap_49',
#  'ask_size_gap_50',
#  'ask_size_gap_51',
#  'ask_size_gap_52',
#  'ask_size_gap_53',
#  'ask_size_gap_54',
#  'ask_size_gap_55',
#  'wap_gap_1',
#  'wap_gap_2',
#  'wap_gap_3',
#  'wap_gap_4',
#  'wap_gap_5',
#  'wap_gap_6',
#  'wap_gap_7',
#  'wap_gap_8',
#  'wap_gap_9',
#  'wap_gap_10',
#  'wap_gap_11',
#  'wap_gap_12',
#  'wap_gap_13',
#  'wap_gap_14',
#  'wap_gap_15',
#  'wap_gap_16',
#  'wap_gap_17',
#  'wap_gap_18',
#  'wap_gap_19',
#  'wap_gap_20',
#  'wap_gap_21',
#  'wap_gap_22',
#  'wap_gap_23',
#  'wap_gap_24',
#  'wap_gap_25',
#  'wap_gap_26',
#  'wap_gap_27',
#  'wap_gap_28',
#  'wap_gap_29',
#  'wap_gap_30',
#  'wap_gap_31',
#  'wap_gap_32',
#  'wap_gap_33',
#  'wap_gap_34',
#  'wap_gap_35',
#  'wap_gap_36',
#  'wap_gap_37',
#  'wap_gap_38',
#  'wap_gap_39',
#  'wap_gap_40',
#  'wap_gap_41',
#  'wap_gap_42',
#  'wap_gap_43',
#  'wap_gap_44',
#  'wap_gap_45',
#  'wap_gap_46',
#  'wap_gap_47',
#  'wap_gap_48',
#  'wap_gap_49',
#  'wap_gap_50',
#  'wap_gap_51',
#  'wap_gap_52',
#  'wap_gap_53',
#  'wap_gap_54',
#  'wap_gap_55',
#  'bid_ask_imb_minus_gap_1',
#  'bid_ask_imb_minus_gap_2',
#  'bid_ask_imb_minus_gap_3',
#  'bid_ask_imb_minus_gap_4',
#  'bid_ask_imb_minus_gap_5',
#  'bid_ask_imb_minus_gap_6',
#  'bid_ask_imb_minus_gap_7',
#  'bid_ask_imb_minus_gap_8',
#  'bid_ask_imb_minus_gap_9',
#  'bid_ask_imb_minus_gap_10',
#  'bid_ask_imb_minus_gap_11',
#  'bid_ask_imb_minus_gap_12',
#  'bid_ask_imb_minus_gap_13',
#  'bid_ask_imb_minus_gap_14',
#  'bid_ask_imb_minus_gap_15',
#  'bid_ask_imb_minus_gap_16',
#  'bid_ask_imb_minus_gap_17',
#  'bid_ask_imb_minus_gap_18',
#  'bid_ask_imb_minus_gap_19',
#  'bid_ask_imb_minus_gap_20',
#  'bid_ask_imb_minus_gap_21',
#  'bid_ask_imb_minus_gap_22',
#  'bid_ask_imb_minus_gap_23',
#  'bid_ask_imb_minus_gap_24',
#  'bid_ask_imb_minus_gap_25',
#  'bid_ask_imb_minus_gap_26',
#  'bid_ask_imb_minus_gap_27',
#  'bid_ask_imb_minus_gap_28',
#  'bid_ask_imb_minus_gap_29',
#  'bid_ask_imb_minus_gap_30',
#  'bid_ask_imb_minus_gap_31',
#  'bid_ask_imb_minus_gap_32',
#  'bid_ask_imb_minus_gap_33',
#  'bid_ask_imb_minus_gap_34',
#  'bid_ask_imb_minus_gap_35',
#  'bid_ask_imb_minus_gap_36',
#  'bid_ask_imb_minus_gap_37',
#  'bid_ask_imb_minus_gap_38',
#  'bid_ask_imb_minus_gap_39',
#  'bid_ask_imb_minus_gap_40',
#  'bid_ask_imb_minus_gap_41',
#  'bid_ask_imb_minus_gap_42',
#  'bid_ask_imb_minus_gap_43',
#  'bid_ask_imb_minus_gap_44',
#  'bid_ask_imb_minus_gap_45',
#  'bid_ask_imb_minus_gap_46',
#  'bid_ask_imb_minus_gap_47',
#  'bid_ask_imb_minus_gap_48',
#  'bid_ask_imb_minus_gap_49',
#  'bid_ask_imb_minus_gap_50',
#  'bid_ask_imb_minus_gap_51',
#  'bid_ask_imb_minus_gap_52',
#  'bid_ask_imb_minus_gap_53',
#  'bid_ask_imb_minus_gap_54',
#  'bid_ask_imb_minus_gap_55',
#  'imbalance_match_imb_minus_gap_1',
#  'imbalance_match_imb_minus_gap_2',
#  'imbalance_match_imb_minus_gap_3',
#  'imbalance_match_imb_minus_gap_4',
#  'imbalance_match_imb_minus_gap_5',
#  'imbalance_match_imb_minus_gap_6',
#  'imbalance_match_imb_minus_gap_7',
#  'imbalance_match_imb_minus_gap_8',
#  'imbalance_match_imb_minus_gap_9',
#  'imbalance_match_imb_minus_gap_10',
#  'imbalance_match_imb_minus_gap_11',
#  'imbalance_match_imb_minus_gap_12',
#  'imbalance_match_imb_minus_gap_13',
#  'imbalance_match_imb_minus_gap_14',
#  'imbalance_match_imb_minus_gap_15',
#  'imbalance_match_imb_minus_gap_16',
#  'imbalance_match_imb_minus_gap_17',
#  'imbalance_match_imb_minus_gap_18',
#  'imbalance_match_imb_minus_gap_19',
#  'imbalance_match_imb_minus_gap_20',
#  'imbalance_match_imb_minus_gap_21',
#  'imbalance_match_imb_minus_gap_22',
#  'imbalance_match_imb_minus_gap_23',
#  'imbalance_match_imb_minus_gap_24',
#  'imbalance_match_imb_minus_gap_25',
#  'imbalance_match_imb_minus_gap_26',
#  'imbalance_match_imb_minus_gap_27',
#  'imbalance_match_imb_minus_gap_28',
#  'imbalance_match_imb_minus_gap_29',
#  'imbalance_match_imb_minus_gap_30',
#  'imbalance_match_imb_minus_gap_31',
#  'imbalance_match_imb_minus_gap_32',
#  'imbalance_match_imb_minus_gap_33',
#  'imbalance_match_imb_minus_gap_34',
#  'imbalance_match_imb_minus_gap_35',
#  'imbalance_match_imb_minus_gap_36',
#  'imbalance_match_imb_minus_gap_37',
#  'imbalance_match_imb_minus_gap_38',
#  'imbalance_match_imb_minus_gap_39',
#  'imbalance_match_imb_minus_gap_40',
#  'imbalance_match_imb_minus_gap_41',
#  'imbalance_match_imb_minus_gap_42',
#  'imbalance_match_imb_minus_gap_43',
#  'imbalance_match_imb_minus_gap_44',
#  'imbalance_match_imb_minus_gap_45',
#  'imbalance_match_imb_minus_gap_46',
#  'imbalance_match_imb_minus_gap_47',
#  'imbalance_match_imb_minus_gap_48',
#  'imbalance_match_imb_minus_gap_49',
#  'imbalance_match_imb_minus_gap_50',
#  'imbalance_match_imb_minus_gap_51',
#  'imbalance_match_imb_minus_gap_52',
#  'imbalance_match_imb_minus_gap_53',
#  'imbalance_match_imb_minus_gap_54',
#  'imbalance_match_imb_minus_gap_55',
#  'second_sin',
#  'second_cos']

# %% [markdown]
# ## featuring engineering

# %%
eps = 1e-3
def feature_engineer_for_index(x, date, time):
    #x = x.filter(((pl.col('seconds_in_bucket') <= time) & (pl.col('date_id') == date)) | (pl.col('date_id') < date) )
    x = x.filter(((pl.col('seconds_in_bucket') <= time) & (pl.col('date_id') == date)) )
    feature_suffix = 'part_1'
    aggs = [
        *[pl.col(c).quantile(0.1, "nearest").alias(f"{c}_quantile1_{feature_suffix}") for c in NUMS],
        *[pl.col(c).quantile(0.2, "nearest").alias(f"{c}_quantile2_{feature_suffix}") for c in NUMS],
        *[pl.col(c).quantile(0.3, "nearest").alias(f"{c}_quantile3_{feature_suffix}") for c in NUMS],
        *[pl.col(c).quantile(0.4, "nearest").alias(f"{c}_quantile4_{feature_suffix}") for c in NUMS],
        *[pl.col(c).quantile(0.5, "nearest").alias(f"{c}_quantile5_{feature_suffix}") for c in NUMS],
        *[pl.col(c).quantile(0.6, "nearest").alias(f"{c}_quantile6_{feature_suffix}") for c in NUMS],
        *[pl.col(c).quantile(0.7, "nearest").alias(f"{c}_quantile7_{feature_suffix}") for c in NUMS],
        *[pl.col(c).quantile(0.8, "nearest").alias(f"{c}_quantile8_{feature_suffix}") for c in NUMS],
        *[pl.col(c).quantile(0.9, "nearest").alias(f"{c}_quantile9_{feature_suffix}") for c in NUMS],
        *[pl.col(c).mean().alias(f"{c}_mean_{feature_suffix}") for c in NUMS],
        *[pl.col(c).std().alias(f"{c}_std_{feature_suffix}") for c in NUMS],
        *[pl.col(c).min().alias(f"{c}_min_{feature_suffix}") for c in NUMS],
        *[pl.col(c).max().alias(f"{c}_max_{feature_suffix}") for c in NUMS],
        *[pl.col(c).median().alias(f"{c}_median_{feature_suffix}") for c in NUMS],
        *[pl.col(c).sum().alias(f"{c}_sum_{feature_suffix}") for c in NUMS],
        *[pl.col(c).skew().alias(f"{c}_skew_{feature_suffix}") for c in NUMS],
        *[pl.col(c).kurtosis().alias(f"{c}_kurtosis_{feature_suffix}") for c in NUMS],
        # adding rank features
        *[pl.col(c).last().alias(f"{c}_rank_{feature_suffix}") for c in NUMS],
        ]

    features_part_1= x.groupby(["stock_id"], maintain_order=True).agg(aggs)
    
    x = x.filter((pl.col('seconds_in_bucket') == time) & (pl.col('date_id') == date))
    df = x.join(features_part_1, on='stock_id')
    # df = df.join(features_part_2, on=['stock_id', 'seconds_in_bucket'])
    # df = df.join(features_part_3, on=['seconds_in_bucket'])
    #df = df.filter((pl.col('seconds_in_bucket') == time) & (pl.col('date_id') == date))
    #df = df.to_pandas()
    
    return df

# %%
train = []
for date in tqdm(range(301, 481)):
    for t in range(0, 550, 10):
        train.append(feature_engineer_for_index(df, date, t))
train = pl.concat(train)
train = train.to_pandas()
train.dropna(subset=['target'], inplace=True)
# Out:
# 100%|██████████| 180/180 [39:02<00:00, 13.01s/it]

# %%
# some cleaning...
null = train.isnull().sum().sort_values(ascending=False) / len(train)
drop = list(null[null>0.9].index)


for col in train.columns:
    if train[col].nunique()==1:
        drop.append(col)
print("*********df DONE*********")

# %%
FEATURES = [c for c in train.columns if c not in drop + ['target', 'date_id']]

# %%
len(FEATURES)

# %% [markdown]
# ## train & val split

# %%
def create_mlp(num_columns, hidden_units=[256,512,1024,1024,512,256], lr = 1e-3):
    
    inp = tf.keras.layers.Input(shape = (num_columns, ))
    out = keras.Sequential(
    [
        keras.layers.Dense(512, activation="tanh",),
        #keras.layers.Dropout(0.1),
        keras.layers.Dense(512, activation="tanh"),
        #keras.layers.Dropout(0.1),
        keras.layers.Dense(256, activation="tanh"),
        #keras.layers.Dropout(0.1),
        keras.layers.Dense(1,),
    ]
    )(inp)
    
    
    model = tf.keras.models.Model(inputs = inp, outputs = [out])
    model.compile(optimizer = tf.keras.optimizers.AdamW(learning_rate = lr),
                  loss = "MAE",
                  metrics =[tf.keras.metrics.MeanAbsoluteError()]
                            , 
                 )
    
    return model

# %%
train = train.fillna(0).clip(-1e9, 1e9)

train_mean = train[FEATURES].mean()
train_std = train[FEATURES].std()

train_min = train[FEATURES].min()
train_max = train[FEATURES].max()

df[FEATURES] = (train[FEATURES] - train_min) /  (train_max - train_min)
df = df.fillna(0).clip(-1e9, 1e9)

# %%
train_df = train[train['date_id']< 450]
val_df = train[train['date_id'] >= 450 ]

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                                                    patience=10,
                                                    mode='min')


target_name = 'target'


     # TRAIN DATA
best_weights_filepath = f'./mlp/best_weights_{i}.hdf5'
save_chk=tf.keras.callbacks.ModelCheckpoint(best_weights_filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

train_x = train_df[FEATURES]
train_y = train_df[[target_name]]

# VALID DATA
valid_x = val_df[FEATURES]
valid_y = val_df[[target_name]]

print(i+1, ', ', end='')
clf = create_ae_mlp(num_columns=len(FEATURES), hidden_units=[256,512,1024,1024,512,256], lr = 1e-3)
#best_iteration_xgb[str(i)].append(clf.best_ntree_limit)

history = clf.fit(train_x.astype('float32').values, train_y[target_name].values, epochs=50,
                  validation_data=(valid_x.astype('float32').values, valid_y[target_name].values),
                  callbacks=[early_stopping,save_chk],
                 batch_size=64,
                 )
clf.load_weights(best_weights_filepath)

score = mean_absolute_error(valid_y['target'], clf.predict(valid_x))
print(score)

# %% [markdown]
# ## eval

# %%
mean_absolute_error(valid_y['target'], clf.predict(valid_x))

# %%
mean_absolute_error(valid_y['target'], clf.predict(valid_x))
# Out:
# 5.8080751022665185

# %%
# !ls
# Out:
# example_test_files  optiver-trading-at-the-close.zip   train_gru.ipynb
# features.npy	    public_timeseries_testing_util.py  xgb_5fold
# lgbm_5fold	    public_train_baseline.ipynb        xgb_5fold.zip
# lgbm.zip	    train_baseline.ipynb
# optiver2023	    train.csv

# %%
# !wc -l ./example_test_files/sample_submission.csv
# Out:
# 33001 ./example_test_files/sample_submission.csv

# %%
# baseline 5.90734 
# light gbm 5.8321366685330425
# cat boost 5.836515258358157

# %% [markdown]
# ## retraining total

# %%
np.save('./lgbm_5fold/features', FEATURES)

# %%
model_name = 'lgbm'
train_x, train_y = train[FEATURES], train[['target']]
feature_importance_df = pd.DataFrame()
if model_name == 'lgbm':
    clf = LGBMRegressor(**lgbm_params) 
else:
    clf = XGBRegressor(**xgb_params)
clf.fit(train_x.astype('float32'), train_y['target'],
        verbose=0)

if model_name == 'lgbm':
    clf.booster_.save_model(f'./lgbm_5fold/final_lgbm.xgb')
elif model_name == 'xgb':
    clf.save_model(f'./xgb_5fold/final_XGB.xgb')
else:
    clf.save_model(f'./cat_5fold/final_cat.xgb')
#best_iteration_xgb[str(i)].append(clf.best_ntree_limit)
# Out:
# /usr/local/lib/python3.8/dist-packages/lightgbm/engine.py:118: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))

# %%
# !zip -r lgbm.zip lgbm_5fold
# Out:
# updating: lgbm_5fold/ (stored 0%)
# updating: lgbm_5fold/lgbm.xgb (deflated 58%)
# updating: lgbm_5fold/final_lgbm.xgb (deflated 58%)
# updating: lgbm_5fold/features.npy (deflated 96%)
