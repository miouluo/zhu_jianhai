# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
s = pd.Series([1,2,3,6,5,8,9])

# %%
s.index.name = '索引'
s
# Out:
# 索引
# 0    1
# 1    2
# 2    3
# 3    6
# 4    5
# 5    8
# 6    9
# dtype: int64

# %%
data = pd.date_range('20231105',periods=6)
print(data)
# Out:
# DatetimeIndex(['2023-11-05', '2023-11-06', '2023-11-07', '2023-11-08',
#                '2023-11-09', '2023-11-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
df1 = pd.DataFrame(np.random.randn(6,4),index=data,columns=list('ABCD'))
df1
# Out:
#                    A         B         C         D
# 2023-11-05 -0.243831  0.346724  1.550741 -2.185189
# 2023-11-06  1.828736 -0.306260  0.410077  0.349708
# 2023-11-07  0.033277 -0.996510  0.361961 -0.756727
# 2023-11-08  1.116873  1.388310 -0.220544  1.158484
# 2023-11-09  0.454019 -1.130069 -0.131413  0.961893
# 2023-11-10 -0.538975  1.224838  0.706625 -0.805893

# %%
df1.index
# Out:
# DatetimeIndex(['2023-11-05', '2023-11-06', '2023-11-07', '2023-11-08',
#                '2023-11-09', '2023-11-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
df1.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df = pd.read_excel('D:\\BaiduNetdiskDownload\\python\\课程中用到的数据\\豆瓣电影数据.xlsx')

# %%
df.head()
# Out:
#    Unnamed: 0      名字      投票人数        类型    产地                 上映时间   时长  \
# 0           0  肖申克的救赎  692795.0     剧情/犯罪    美国  1994-09-10 00:00:00  142
# 1           1    控方证人   42995.0  剧情/悬疑/犯罪    美国  1957-12-17 00:00:00  116
# 2           2   美丽人生   327855.0  剧情/喜剧/爱情   意大利  1997-12-20 00:00:00  116
# 3           3    阿甘正传  580897.0     剧情/爱情    美国  1994-06-23 00:00:00  142
# 4           4    霸王别姬  478523.0  剧情/爱情/同性  中国大陆  1993-01-01 00:00:00  171
#
#      年代   评分    首映地点
# 0  1994  9.6  多伦多电影节
# 1  1957  9.5      美国
# 2  1997  9.5     意大利
# 3  1994  9.4   洛杉矶首映
# 4  1993  9.4      香港

# %%
df.iloc[0]
# Out:
# Unnamed: 0                      0
# 名字                         肖申克的救赎
# 投票人数                     692795.0
# 类型                          剧情/犯罪
# 产地                             美国
# 上映时间          1994-09-10 00:00:00
# 时长                            142
# 年代                           1994
# 评分                            9.6
# 首映地点                       多伦多电影节
# Name: 0, dtype: object

# %%
df.iloc[0:5]
# Out:
#    Unnamed: 0      名字      投票人数        类型    产地                 上映时间   时长  \
# 0           0  肖申克的救赎  692795.0     剧情/犯罪    美国  1994-09-10 00:00:00  142
# 1           1    控方证人   42995.0  剧情/悬疑/犯罪    美国  1957-12-17 00:00:00  116
# 2           2   美丽人生   327855.0  剧情/喜剧/爱情   意大利  1997-12-20 00:00:00  116
# 3           3    阿甘正传  580897.0     剧情/爱情    美国  1994-06-23 00:00:00  142
# 4           4    霸王别姬  478523.0  剧情/爱情/同性  中国大陆  1993-01-01 00:00:00  171
#
#      年代   评分    首映地点
# 0  1994  9.6  多伦多电影节
# 1  1957  9.5      美国
# 2  1997  9.5     意大利
# 3  1994  9.4   洛杉矶首映
# 4  1993  9.4      香港

# %% [markdown]
# 添加一行

# %%
dit = {'名字':'复仇者联盟3','投票人数':123456,'类型':'剧情','产地':'美国','上映时间':'2018-05-4 00:00:00','时长':142,'年代':2018,'评分':8.7}
s = pd.Series(dit)
s.name = 38738

# %%
s
# Out:
# 名字                  复仇者联盟3
# 投票人数                123456
# 类型                      剧情
# 产地                      美国
# 上映时间    2018-05-4 00:00:00
# 时长                     142
# 年代                    2018
# 评分                     8.7
# Name: 38738, dtype: object

# %%
df = df.append(s)
# Out:
# C:\Users\xiaoqian\AppData\Local\Temp\ipykernel_21240\2145843730.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s)

# %%
df.tail()
# Out:
#        Unnamed: 0                                                 名字  \
# 38734     38734.0                                              1935年
# 38735     38735.0                                               血溅画屏
# 38736     38736.0                                             魔窟中的幻想
# 38737     38737.0  列宁格勒围困之星火战役 Блокада: Фильм 2: Ленинградский ме...
# 38738         NaN                                             复仇者联盟3
#
#            投票人数              类型    产地                 上映时间   时长    年代   评分  \
# 38734      57.0           喜剧/歌舞    美国  1935-03-15 00:00:00   98  1935  7.6
# 38735      95.0  剧情/悬疑/犯罪/武侠/古装  中国大陆  1905-06-08 00:00:00   91  1986  7.1
# 38736      51.0        惊悚/恐怖/儿童  中国大陆  1905-06-08 00:00:00   78  1986  8.0
# 38737      32.0           剧情/战争    苏联  1905-05-30 00:00:00   97  1977  6.6
# 38738  123456.0              剧情    美国   2018-05-4 00:00:00  142  2018  8.7
#
#       首映地点
# 38734   美国
# 38735   美国
# 38736   美国
# 38737   美国
# 38738  NaN

# %%
df = df.drop(38738)

# %%
df.tail()
# Out:
#        Unnamed: 0                                                 名字  投票人数  \
# 38733     38733.0                                              神学院 S  46.0
# 38734     38734.0                                              1935年  57.0
# 38735     38735.0                                               血溅画屏  95.0
# 38736     38736.0                                             魔窟中的幻想  51.0
# 38737     38737.0  列宁格勒围困之星火战役 Блокада: Фильм 2: Ленинградский ме...  32.0
#
#                    类型    产地                 上映时间  时长    年代   评分 首映地点
# 38733           Adult    法国  1905-06-05 00:00:00  58  1983  8.6   美国
# 38734           喜剧/歌舞    美国  1935-03-15 00:00:00  98  1935  7.6   美国
# 38735  剧情/悬疑/犯罪/武侠/古装  中国大陆  1905-06-08 00:00:00  91  1986  7.1   美国
# 38736        惊悚/恐怖/儿童  中国大陆  1905-06-08 00:00:00  78  1986  8.0   美国
# 38737           剧情/战争    苏联  1905-05-30 00:00:00  97  1977  6.6   美国

# %%
df.columns
# Out:
# Index(['Unnamed: 0', '名字', '投票人数', '类型', '产地', '上映时间', '时长', '年代', '评分',
#        '首映地点'],
#       dtype='object')

# %%
df['名字'][0:5]
# Out:
# 0    肖申克的救赎
# 1      控方证人
# 2     美丽人生
# 3      阿甘正传
# 4      霸王别姬
# Name: 名字, dtype: object

# %%
#取多列
dfa = df[['名字','类型']]

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 plt.pie(dfa)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:2799, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch, data)
#    2792 @_copy_docstring_and_deprecators(Axes.pie)
#    2793 def pie(
#    2794         x, explode=None, labels=None, colors=None, autopct=None,
#    (...)
#    2797         textprops=None, center=(0, 0), frame=False,
#    2798         rotatelabels=False, *, normalize=True, hatch=None, data=None):
# -> 2799     return gca().pie(
#    2800         x, explode=explode, labels=labels, colors=colors,
#    2801         autopct=autopct, pctdistance=pctdistance, shadow=shadow,
# ...

# %%
#增加列
df['dy_num'] = 1
df.head()
# Out:
#    Unnamed: 0      名字      投票人数        类型    产地                 上映时间   时长  \
# 0         0.0  肖申克的救赎  692795.0     剧情/犯罪    美国  1994-09-10 00:00:00  142
# 1         1.0    控方证人   42995.0  剧情/悬疑/犯罪    美国  1957-12-17 00:00:00  116
# 2         2.0   美丽人生   327855.0  剧情/喜剧/爱情   意大利  1997-12-20 00:00:00  116
# 3         3.0    阿甘正传  580897.0     剧情/爱情    美国  1994-06-23 00:00:00  142
# 4         4.0    霸王别姬  478523.0  剧情/爱情/同性  中国大陆  1993-01-01 00:00:00  171
#
#      年代   评分    首映地点  dy_num
# 0  1994  9.6  多伦多电影节       1
# 1  1957  9.5      美国       1
# 2  1997  9.5     意大利       1
# 3  1994  9.4   洛杉矶首映       1
# 4  1993  9.4      香港       1

# %%
#列删除，axis=1是列，0为行
df = df.drop('dy_num',axis = 1)
df = df.drop('Unnamed: 0',axis = 1)
df.head()
# Out:
#        名字      投票人数        类型    产地                 上映时间   时长    年代   评分  \
# 0  肖申克的救赎  692795.0     剧情/犯罪    美国  1994-09-10 00:00:00  142  1994  9.6
# 1    控方证人   42995.0  剧情/悬疑/犯罪    美国  1957-12-17 00:00:00  116  1957  9.5
# 2   美丽人生   327855.0  剧情/喜剧/爱情   意大利  1997-12-20 00:00:00  116  1997  9.5
# 3    阿甘正传  580897.0     剧情/爱情    美国  1994-06-23 00:00:00  142  1994  9.4
# 4    霸王别姬  478523.0  剧情/爱情/同性  中国大陆  1993-01-01 00:00:00  171  1993  9.4
#
#      首映地点
# 0  多伦多电影节
# 1      美国
# 2     意大利
# 3   洛杉矶首映
# 4      香港

# %%
df.loc[1,'名字']
# Out:
# '控方证人'

# %%
df.loc[[1,3,5,9,11,13,15],['名字','评分']]
# Out:
#           名字   评分
# 1       控方证人  9.5
# 3       阿甘正传  9.4
# 5     泰坦尼克号   9.4
# 9   这个杀手不太冷   9.4
# 11     疯狂动物城  9.3
# 13       海豚湾  9.3
# 15   机器人总动员   9.3

# %%
df2 = pd.DataFrame(df.loc[[1,3,5,9,11,13,15],['名字','评分']])

# %%
df2 = df2.reset_index()
df2 = df2.drop('index',axis=1)
df2
# Out:
#          名字   评分
# 0      控方证人  9.5
# 1      阿甘正传  9.4
# 2    泰坦尼克号   9.4
# 3  这个杀手不太冷   9.4
# 4     疯狂动物城  9.3
# 5       海豚湾  9.3
# 6   机器人总动员   9.3

# %%
df[df['产地'] == '美国'].head() #对特定内容提取
# Out:
#        名字      投票人数        类型  产地                 上映时间   时长    年代   评分    首映地点
# 0  肖申克的救赎  692795.0     剧情/犯罪  美国  1994-09-10 00:00:00  142  1994  9.6  多伦多电影节
# 1    控方证人   42995.0  剧情/悬疑/犯罪  美国  1957-12-17 00:00:00  116  1957  9.5      美国
# 3    阿甘正传  580897.0     剧情/爱情  美国  1994-06-23 00:00:00  142  1994  9.4   洛杉矶首映
# 5  泰坦尼克号   157074.0  剧情/爱情/灾难  美国  2012-04-10 00:00:00  194  2012  9.4    中国大陆
# 6  辛德勒的名单  306904.0  剧情/历史/战争  美国  1993-11-30 00:00:00  195  1993  9.4   华盛顿首映

# %%
df[(df['产地'] == '美国')&(df['评分'] > 9)].head()
# Out:
#        名字      投票人数        类型  产地                 上映时间   时长    年代   评分    首映地点
# 0  肖申克的救赎  692795.0     剧情/犯罪  美国  1994-09-10 00:00:00  142  1994  9.6  多伦多电影节
# 1    控方证人   42995.0  剧情/悬疑/犯罪  美国  1957-12-17 00:00:00  116  1957  9.5      美国
# 3    阿甘正传  580897.0     剧情/爱情  美国  1994-06-23 00:00:00  142  1994  9.4   洛杉矶首映
# 5  泰坦尼克号   157074.0  剧情/爱情/灾难  美国  2012-04-10 00:00:00  194  2012  9.4    中国大陆
# 6  辛德勒的名单  306904.0  剧情/历史/战争  美国  1993-11-30 00:00:00  195  1993  9.4   华盛顿首映

# %%
df[(df.产地 == '美国')&(df.评分> 9)].head()
# Out:
#        名字      投票人数        类型  产地                 上映时间   时长    年代   评分    首映地点
# 0  肖申克的救赎  692795.0     剧情/犯罪  美国  1994-09-10 00:00:00  142  1994  9.6  多伦多电影节
# 1    控方证人   42995.0  剧情/悬疑/犯罪  美国  1957-12-17 00:00:00  116  1957  9.5      美国
# 3    阿甘正传  580897.0     剧情/爱情  美国  1994-06-23 00:00:00  142  1994  9.4   洛杉矶首映
# 5  泰坦尼克号   157074.0  剧情/爱情/灾难  美国  2012-04-10 00:00:00  194  2012  9.4    中国大陆
# 6  辛德勒的名单  306904.0  剧情/历史/战争  美国  1993-11-30 00:00:00  195  1993  9.4   华盛顿首映

# %%
df[((df.产地 == '美国')|(df.产地 == '中国大陆'))&(df.评分> 9)].head()
# Out:
#        名字      投票人数        类型    产地                 上映时间   时长    年代   评分  \
# 0  肖申克的救赎  692795.0     剧情/犯罪    美国  1994-09-10 00:00:00  142  1994  9.6
# 1    控方证人   42995.0  剧情/悬疑/犯罪    美国  1957-12-17 00:00:00  116  1957  9.5
# 3    阿甘正传  580897.0     剧情/爱情    美国  1994-06-23 00:00:00  142  1994  9.4
# 4    霸王别姬  478523.0  剧情/爱情/同性  中国大陆  1993-01-01 00:00:00  171  1993  9.4
# 5  泰坦尼克号   157074.0  剧情/爱情/灾难    美国  2012-04-10 00:00:00  194  2012  9.4
#
#      首映地点
# 0  多伦多电影节
# 1      美国
# 3   洛杉矶首映
# 4      香港
# 5    中国大陆

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38738 entries, 0 to 38737
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   名字      38178 non-null  object
#  1   投票人数    38738 non-null  float64
#  2   类型      38738 non-null  object
#  3   产地      38738 non-null  object
#  4   上映时间    38736 non-null  object
#  5   时长      38738 non-null  object
#  6   年代      38738 non-null  object
#  7   评分      38738 non-null  float64
#  8   首映地点    38737 non-null  object
# dtypes: float64(2), object(7)
# memory usage: 4.0+ MB

# %%
df[df['名字'].isnull()]
# Out:
#         名字    投票人数        类型  产地                 上映时间   时长    年代   评分 首映地点
# 231    NaN   144.0    纪录片/音乐  韩国  2011-02-02 00:00:00   90  2011  9.7   美国
# 361    NaN    80.0        短片  其他  1905-05-17 00:00:00    4  1964  5.7   美国
# 369    NaN  5315.0        剧情  日本  2004-07-10 00:00:00  111  2004  7.5   日本
# 372    NaN   263.0     短片/音乐  英国  1998-06-30 00:00:00   34  1998  9.2   美国
# 374    NaN    47.0        短片  其他  1905-05-17 00:00:00    3  1964  6.7   美国
# ...    ...     ...       ...  ..                  ...  ...   ...  ...  ...
# 38523  NaN  2190.0  动作/恐怖/战争  日本  1905-06-27 00:00:00   85  2005  7.0   美国
# 38555  NaN    32.0       纪录片  美国  1905-06-19 00:00:00   88  1997  8.1   美国
# 38560  NaN    49.0    纪录片/音乐  美国  2004-09-25 00:00:00  107  2004  8.4   美国
# 38643  NaN    62.0        恐怖  美国  2003-12-30 00:00:00   90  2003  5.2   美国
# 38656  NaN    54.0     喜剧/恐怖  其他  2004-01-29 00:00:00   30  2004  8.7   美国
#
# [560 rows x 9 columns]

# %%
df['评分'].fillna(np.mean(df['评分']),inplace=True) #inplace可以直接替换到原来的数据

# %%
df1 = df.fillna('未知电影')
df1[df1['名字'].isnull()]
# Out:
# Empty DataFrame
# Columns: [名字, 投票人数, 类型, 产地, 上映时间, 时长, 年代, 评分, 首映地点]
# Index: []

# %%
len(df)
# Out:
# 38738

# %%
df2 = df.dropna()

# %%
len(df2)
# Out:
# 38175

# %%
df.dropna(inplace=True)
len(df)
# Out:
# 38175

# %%
df[df['投票人数']<0]
# Out:
#                                           名字   投票人数     类型    产地  \
# 19777                               皇家大贼 皇家大  -80.0  剧情/犯罪  中国香港
# 19786  日本的垃圾去中国大陆 にっぽんの“ゴミ” 大陆へ渡る ～中国式リサイクル錬  -80.0    纪录片    日本
# 19797                                    女教徒 -118.0     剧情    法国
#
#                       上映时间   时长    年代   评分 首映地点
# 19777  1985-05-31 00:00:00   60  1985  6.3   美国
# 19786  1905-06-26 00:00:00   60  2004  7.9   美国
# 19797  1966-05-06 00:00:00  135  1966  7.8   美国

# %%
df[df['投票人数']%1!=0]
# Out:
#                       名字   投票人数           类型  产地                 上映时间   时长  \
# 19791             女教师 女教   8.30        剧情/犯罪  日本  1977-10-29 00:00:00  100
# 19804  女郎漫游仙境 ドレミファ娘の血は騒   5.90        喜剧/歌舞  日本  1985-11-03 00:00:00   80
# 19820               女仆日记  12.87           剧情  法国  2015-04-01 00:00:00   96
# 38055              逃出亚卡拉  12.87  剧情/动作/惊悚/犯罪  美国  1979-09-20 00:00:00  112
#
#          年代   评分 首映地点
# 19791  1977  6.6   日本
# 19804  1985  6.7   日本
# 19820  2015  5.7   法国
# 38055  1979  7.8   美国

# %%
df = df[df['投票人数']>0]
df = df[df['投票人数']%1==0]
len(df)
# Out:
# 38168

# %%
df.to_excel('D:\\BaiduNetdiskDownload\\python\\课程中用到的数据\\movie_data.xlsx')

# %%
df = pd.read_excel('D:\\BaiduNetdiskDownload\\python\\课程中用到的数据\\movie_data.xlsx')

# %%
df.head()
# Out:
#    Unnamed: 0      名字    投票人数        类型    产地                 上映时间   时长    年代  \
# 0           0  肖申克的救赎  692795     剧情/犯罪    美国  1994-09-10 00:00:00  142  1994
# 1           1    控方证人   42995  剧情/悬疑/犯罪    美国  1957-12-17 00:00:00  116  1957
# 2           2   美丽人生   327855  剧情/喜剧/爱情   意大利  1997-12-20 00:00:00  116  1997
# 3           3    阿甘正传  580897     剧情/爱情    美国  1994-06-23 00:00:00  142  1994
# 4           4    霸王别姬  478523  剧情/爱情/同性  中国大陆  1993-01-01 00:00:00  171  1993
#
#     评分    首映地点
# 0  9.6  多伦多电影节
# 1  9.5      美国
# 2  9.5     意大利
# 3  9.4   洛杉矶首映
# 4  9.4      香港

# %%
df['投票人数'].dtype
# Out:
# dtype('int64')

# %%
df['投票人数'] = df['投票人数'].astype('int')

# %%
df['产地'].dtype
# Out:
# dtype('O')

# %%
df['产地'] = df['产地'].astype('str')

# %%
df[df['年代']=='2008\u200e']
# Out:
#        Unnamed: 0    名字  投票人数  类型    产地                 上映时间  时长     年代   评分  \
# 14934       15205  狂蟒惊魂   544  恐怖  中国大陆  2008-04-08 00:00:00  93  2008‎  2.7
#
#       首映地点
# 14934   美国

# %%
df.loc[14934,'年代'] = 2008

# %%
df['年代'] = df['年代'].astype('int')

# %%
df['时长'] = df['时长'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df['时长'] = df['时长'].astype('int')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:448, in BaseBlockManager.astype(self, dtype, copy, errors)
#     447 def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# ...

# %%
df[df['时长']=='8U']

# %%
df.drop([31169],inplace=True)

# %%
df['时长'] = df['时长'].astype('int')

# %%
df[df['时长']=='12J']

# %%
df.drop([32458],inplace=True)

# %%
df.drop([13625],inplace=True)

# %%
df['时长'] = df['时长'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df['时长'] = df['时长'].astype('int')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:448, in BaseBlockManager.astype(self, dtype, copy, errors)
#     447 def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# ...

# %%
df.head()
# Out:
#    Unnamed: 0      名字    投票人数        类型    产地                 上映时间   时长    年代  \
# 0           0  肖申克的救赎  692795     剧情/犯罪    美国  1994-09-10 00:00:00  142  1994
# 1           1    控方证人   42995  剧情/悬疑/犯罪    美国  1957-12-17 00:00:00  116  1957
# 2           2   美丽人生   327855  剧情/喜剧/爱情   意大利  1997-12-20 00:00:00  116  1997
# 3           3    阿甘正传  580897     剧情/爱情    美国  1994-06-23 00:00:00  142  1994
# 4           4    霸王别姬  478523  剧情/爱情/同性  中国大陆  1993-01-01 00:00:00  171  1993
#
#     评分    首映地点
# 0  9.6  多伦多电影节
# 1  9.5      美国
# 2  9.5     意大利
# 3  9.4   洛杉矶首映
# 4  9.4      香港

# %%
df = df.drop('Unnamed: 0',axis = 1)

# %%
df.sort_values(by = '投票人数',ascending=False).head()
# Out:
#           名字    投票人数              类型  产地                 上映时间   时长    年代   评分  \
# 0     肖申克的救赎  692795           剧情/犯罪  美国  1994-09-10 00:00:00  142  1994  9.6
# 9   这个杀手不太冷   662552        剧情/动作/犯罪  法国  1994-09-14 00:00:00  133  1994  9.4
# 22      盗梦空间  642134  剧情/动作/科幻/悬疑/冒险  美国  2010-09-01 00:00:00  148  2010  9.2
# 3       阿甘正传  580897           剧情/爱情  美国  1994-06-23 00:00:00  142  1994  9.4
# 99   三傻大闹宝莱坞  549808     剧情/喜剧/爱情/歌舞  印度  2011-12-08 00:00:00  171  2009  9.1
#
#       首映地点
# 0   多伦多电影节
# 9       法国
# 22    中国大陆
# 3    洛杉矶首映
# 99    中国大陆

# %%
df.sort_values(by = '年代',ascending=True).head()
# Out:
#             名字  投票人数           类型  产地                 上映时间  时长    年代   评分 首映地点
# 13791     利兹大桥   126           短片  英国              1888-10  60  1888  7.2   美国
# 1499   朗德海花园场景   650           短片  英国           1888-10-14  60  1888  8.7   美国
# 25767      恶作剧    51           短片  美国  1905-03-04 00:00:00  60  1890  4.8   美国
# 10389   可怜的比埃洛   176  喜剧/爱情/动画/短片  法国           1892-10-28  60  1892  7.5   法国
# 14192  迪克森实验音膜   121           短片  美国  1905-03-08 00:00:00  60  1894  7.2   美国

# %%
#多个值排序先按照什么再按照什么
df.sort_values(by=['评分','投票人数'],ascending=False).head()
# Out:
#                      名字  投票人数   类型  产地                 上映时间   时长    年代   评分  \
# 9049           平安结祈 平安結   208   音乐  日本  2012-02-24 00:00:00   60  2012  9.9
# 23190  未作回答的问题：伯恩斯坦哈佛六讲    61  纪录片  美国  1905-05-29 00:00:00   60  1973  9.9
# 24880         索科洛夫：巴黎现场    43   音乐  法国  2002-11-04 00:00:00  127  2002  9.9
# 11236              公园现场   163   音乐  英国  2012-12-03 00:00:00   60  2012  9.8
# 1151               Sant   143  脱口秀  日本  2003-01-01 00:00:00  135  2014  9.8
#
#       首映地点
# 9049    美国
# 23190   美国
# 24880   美国
# 11236   美国
# 1151    美国

# %%
df.describe()
# Out:
#                 投票人数            年代            评分
# count   38167.000000  38167.000000  38167.000000
# mean     6264.895590   1997.940525      6.922132
# std     26291.509168    191.365725      1.263715
# min        21.000000   1888.000000      2.000000
# 25%       101.000000   1990.000000      6.300000
# 50%       354.000000   2005.000000      7.100000
# 75%      1798.000000   2010.000000      7.800000
# max    692795.000000  39180.000000      9.900000

# %%
df[df['年代']>2018]
# Out:
#                    名字  投票人数   类型  产地                 上映时间   时长     年代   评分  \
# 16823  妈妈回来吧-中国打工村的孩子    49  纪录片  日本  2007-04-08 00:00:00  109  39180  8.9
#
#       首映地点
# 16823   美国

# %%
df[df['时长']>1000]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df[df['时长']>1000]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\common.py:72, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      68             return NotImplemented
#      70 other = item_from_zerodim(other)
# ---> 72 return method(self, other)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\arraylike.py:58, in OpsMixin.__gt__(self, other)
#      56 @unpack_zerodim_and_defer("__gt__")
#      57 def __gt__(self, other):
# ---> 58     return self._cmp_method(other, operator.gt)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:6243, in Series._cmp_method(self, other, op)
#    6240 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    6242 with np.errstate(all="ignore"):
# -> 6243     res_values = ops.comparison_op(lvalues, rvalues, op)
# ...

# %%
df.drop(df[df['时长']>1000].index,inplace=True)

# %%
df.drop(df[df['年代']>2018].index,inplace=True)

# %%
df[df['年代']>2018]
# Out:
#                    名字  投票人数   类型  产地                 上映时间   时长     年代   评分  \
# 16823  妈妈回来吧-中国打工村的孩子    49  纪录片  日本  2007-04-08 00:00:00  109  39180  8.9
#
#       首映地点
# 16823   美国

# %%
df[df['时长']>1000]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 df[df['时长']>1000]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\common.py:72, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      68             return NotImplemented
#      70 other = item_from_zerodim(other)
# ---> 72 return method(self, other)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\arraylike.py:58, in OpsMixin.__gt__(self, other)
#      56 @unpack_zerodim_and_defer("__gt__")
#      57 def __gt__(self, other):
# ---> 58     return self._cmp_method(other, operator.gt)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:6243, in Series._cmp_method(self, other, op)
#    6240 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    6242 with np.errstate(all="ignore"):
# -> 6243     res_values = ops.comparison_op(lvalues, rvalues, op)
# ...

# %%
df.index = range(len(df))

# %%
df.head()
# Out:
#        名字    投票人数        类型    产地                 上映时间   时长    年代   评分    首映地点
# 0  肖申克的救赎  692795     剧情/犯罪    美国  1994-09-10 00:00:00  142  1994  9.6  多伦多电影节
# 1    控方证人   42995  剧情/悬疑/犯罪    美国  1957-12-17 00:00:00  116  1957  9.5      美国
# 2   美丽人生   327855  剧情/喜剧/爱情   意大利  1997-12-20 00:00:00  116  1997  9.5     意大利
# 3    阿甘正传  580897     剧情/爱情    美国  1994-06-23 00:00:00  142  1994  9.4   洛杉矶首映
# 4    霸王别姬  478523  剧情/爱情/同性  中国大陆  1993-01-01 00:00:00  171  1993  9.4      香港

# %%
df['投票人数'].max()#求最值
# Out:
# 692795

# %%
df['时长'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 df['时长'].mean()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:11847, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11829 @doc(
#   11830     _num_doc,
#   11831     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11845     **kwargs,
#   11846 ):
# > 11847     return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:11401, in NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11393 def mean(
#   11394     self,
#   11395     axis: Axis | None | lib.NoDefault = lib.no_default,
#    (...)
#   11399     **kwargs,
#   11400 ) -> Series | float:
# > 11401     return self._stat_function(
# ...

# %%
df['时长'].median()#中位数

# %%
df.info()

# %%
df.describe()

# %%
#相关性
df[['投票人数','评分']].corr()

# %%
df[['投票人数','评分']].cov()#求协方差

# %%
len(df)

# %%
df['产地'].unique() #查看唯一值
# Out:
# array(['美国', '意大利', '中国大陆', '日本', '法国', '英国', '韩国', '中国香港', '阿根廷', '德国',
#        '印度', '其他', '加拿大', '波兰', '泰国', '澳大利亚', '西班牙', '俄罗斯', '中国台湾', '荷兰',
#        '丹麦', '比利时', 'USA', '苏联', '巴西', '瑞典', '西德', '墨西哥'], dtype=object)

# %%
df['产地'].replace('USA','美国',inplace=True)

# %%
df['产地'].replace(['西德','苏联'],['德国','俄罗斯'],inplace=True)

# %%
len(df['产地'].unique())
# Out:
# 25

# %%
df['年代'].value_counts().head()
# Out:
# 2012    2018
# 2013    1977
# 2008    1927
# 2014    1867
# 2010    1863
# Name: 年代, dtype: int64

# %%
df['产地'].value_counts().head()
# Out:
# 美国      11714
# 日本       5007
# 中国大陆     3791
# 中国香港     2847
# 法国       2787
# Name: 产地, dtype: int64

# %%
df.to_excel('D:\\BaiduNetdiskDownload\\python\\课程中用到的数据\\movie_data2.xlsx')

# %%
df = pd.read_excel('D:\\BaiduNetdiskDownload\\python\\课程中用到的数据\\movie_data2.xlsx')

# %%
pd.pivot_table(df,index=['年代'])#聚合运算
# Out:
# C:\Users\xiaoqian\AppData\Local\Temp\ipykernel_18344\800372257.py:1: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   pd.pivot_table(df,index=['年代'])#聚合运算
#          Unnamed: 0         投票人数        评分
# 年代
# 1888    7644.500000   388.000000  7.950000
# 1890   25766.000000    51.000000  4.800000
# 1892   10389.000000   176.000000  7.500000
# 1894   15911.333333   112.666667  6.633333
# 1895   12777.125000   959.875000  7.575000
# ...             ...          ...       ...
# 2013   18750.269095  7694.106727  6.375974
# 2014   19040.742367  7803.983931  6.249384
# 2015   19969.639898  7954.999363  6.121925
# 2016   19665.242063  7341.388889  5.834524
# 39180  16822.000000    49.000000  8.900000
#
# [127 rows x 3 columns]

# %%
pd.pivot_table(df,index=['年代','产地'],values=['评分'])
# Out:
#                 评分
# 年代    产地
# 1888  英国  7.950000
# 1890  美国  4.800000
# 1892  法国  7.500000
# 1894  法国  7.000000
#       美国  6.450000
# ...            ...
# 2016  法国  7.300000
#       美国  6.522581
#       英国  7.200000
#       韩国  5.730000
# 39180 日本  8.900000
#
# [1578 rows x 1 columns]

# %%
pd.pivot_table(df,index=['年代','产地'],values=['投票人数'],aggfunc=np.sum)
#aggfunc设定聚合运算的计算设定
# Out:
#             投票人数
# 年代    产地
# 1888  英国     776
# 1890  美国      51
# 1892  法国     176
# 1894  法国     148
#       美国     190
# ...          ...
# 2016  法国     134
#       美国  695902
#       英国  160680
#       韩国   34797
# 39180 日本      49
#
# [1578 rows x 1 columns]

# %%
df = df.drop('Unnamed: 0',axis = 1)

# %%
pd.pivot_table(df,index=['产地'],values=['投票人数','评分'],aggfunc=[np.sum,np.mean],margins=True).head()
# Out:
#            sum                   mean
#           投票人数       评分          投票人数        评分
# 产地
# 中国台湾   5237466   4367.2   8474.864078  7.066667
# 中国大陆  41380993  22984.8  10915.587708  6.062991
# 中国香港  23179448  18430.2   8141.709870  6.473551
# 丹麦      394745   1427.6   2003.781726  7.246701
# 俄罗斯     486082   3597.2   1021.180672  7.557143

# %%
pd.pivot_table(df,index=['产地'],values=['投票人数','评分'],aggfunc={'投票人数':np.sum,'评分':np.mean},fill_value=0)
# Out:
#            投票人数        评分
# 产地
# 中国台湾    5237466  7.066667
# 中国大陆   41380993  6.062991
# 中国香港   23179448  6.473551
# 丹麦       394745  7.246701
# 俄罗斯      486082  7.557143
# 其他      3048849  7.226713
# 加拿大     1362581  6.727221
# 印度      1146173  6.864888
# 墨西哥      139462  7.085470
# 巴西       357027  7.232323
# 德国      2679856  7.187365
# 意大利     2500842  7.183131
# 日本     17981680  7.192910
# 比利时      170449  7.197080
# 法国     10208966  7.243093
# 波兰       159577  7.441989
# 泰国      1564881  6.109184
# 澳大利亚    1415443  6.953559
# 瑞典       289876  7.434392
# 美国    101522430  6.923433
# 英国     13236450  7.498684
# 荷兰       144596  7.160265
# 西班牙     1486383  7.025056
# 阿根廷      258085  7.248673
# 韩国      8759930  6.351118

# %%
table = pd.pivot_table(df,index=['年代'],values=['投票人数','评分'],aggfunc={'投票人数':np.sum,'评分':np.mean},fill_value=0)

# %%
table[table.index == 1994]
# Out:
#          投票人数       评分
# 年代
# 1994  5668165  7.25726

# %%
table.sort_values('评分',ascending=False)
# Out:
#            投票人数        评分
# 年代
# 39180        49  8.900000
# 1924      10382  8.059259
# 1928      16133  7.964103
# 1888        776  7.950000
# 1912        724  7.925000
# ...         ...       ...
# 2013   15211249  6.375974
# 2014   14570038  6.249384
# 2015   12481394  6.121925
# 2016    1850030  5.834524
# 1890         51  4.800000
#
# [127 rows x 2 columns]

# %%
pd.pivot_table(df,index=['年代','产地'],values=['投票人数','评分'],aggfunc={'投票人数':np.sum,'评分':np.mean},fill_value=0)
# Out:
#             投票人数        评分
# 年代    产地
# 1888  英国     776  7.950000
# 1890  美国      51  4.800000
# 1892  法国     176  7.500000
# 1894  法国     148  7.000000
#       美国     190  6.450000
# ...          ...       ...
# 2016  法国     134  7.300000
#       美国  695902  6.522581
#       英国  160680  7.200000
#       韩国   34797  5.730000
# 39180 日本      49  8.900000
#
# [1578 rows x 2 columns]

# %%
df.head()
# Out:
#        名字    投票人数        类型    产地                 上映时间   时长    年代   评分    首映地点
# 0  肖申克的救赎  692795     剧情/犯罪    美国  1994-09-10 00:00:00  142  1994  9.6  多伦多电影节
# 1    控方证人   42995  剧情/悬疑/犯罪    美国  1957-12-17 00:00:00  116  1957  9.5      美国
# 2   美丽人生   327855  剧情/喜剧/爱情   意大利  1997-12-20 00:00:00  116  1997  9.5     意大利
# 3    阿甘正传  580897     剧情/爱情    美国  1994-06-23 00:00:00  142  1994  9.4   洛杉矶首映
# 4    霸王别姬  478523  剧情/爱情/同性  中国大陆  1993-01-01 00:00:00  171  1993  9.4      香港

# %%
s = pd.Series(np.arange(1,10),index=[['a','a','a','b','b','c','c','d','d'],[1,2,3,1,2,3,1,2,3]])
s
# Out:
# a  1    1
#    2    2
#    3    3
# b  1    4
#    2    5
# c  3    6
#    1    7
# d  2    8
#    3    9
# dtype: int32

# %%
s.unstack()#堆叠
# Out:
#      1    2    3
# a  1.0  2.0  3.0
# b  4.0  5.0  NaN
# c  7.0  NaN  6.0
# d  NaN  8.0  9.0

# %%
s.unstack().stack()
# Out:
# a  1    1.0
#    2    2.0
#    3    3.0
# b  1    4.0
#    2    5.0
# c  1    7.0
#    3    6.0
# d  2    8.0
#    3    9.0
# dtype: float64

# %%
data = pd.DataFrame(np.arange(12).reshape(4,3),index=[['a','a','b','b'],[1,2,1,2]],columns=[['A','A','B'],['Q','Z','H']])
data
# Out:
#      A       B
#      Q   Z   H
# a 1  0   1   2
#   2  3   4   5
# b 1  6   7   8
#   2  9  10  11

# %%
#设置是索引名称
data.index.names = ['row1','row2']
data.columns.names = ['col1','col2']
data
# Out:
# col1       A       B
# col2       Q   Z   H
# row1 row2
# a    1     0   1   2
#      2     3   4   5
# b    1     6   7   8
#      2     9  10  11

# %%
df = df.set_index(['产地','年代'])#设置索引为产地二级索引为年代
df
# Out:
#                                                           名字    投票人数  \
# 产地   年代
# 美国   1994                                             肖申克的救赎  692795
#      1957                                               控方证人   42995
# 意大利  1997                                              美丽人生   327855
# 美国   1994                                               阿甘正传  580897
# 中国大陆 1993                                               霸王别姬  478523
# ...                                                      ...     ...
# 法国   1983                                              神学院 S      46
# 美国   1935                                              1935年      57
# 中国大陆 1986                                               血溅画屏      95
#      1986                                             魔窟中的幻想      51
# 俄罗斯  1977  列宁格勒围困之星火战役 Блокада: Фильм 2: Ленинградский ме...      32
#
#                        类型                 上映时间   时长   评分    首映地点
# 产地   年代
# ...

# %%
df.loc['中国大陆'] #通过索引中国大陆查看
# Out:
#             名字    投票人数              类型                 上映时间   时长   评分  首映地点
# 年代
# 1993      霸王别姬  478523        剧情/爱情/同性  1993-01-01 00:00:00  171  9.4    香港
# 1961      大闹天宫   74881           动画/奇幻  1905-05-14 00:00:00  114  9.2    上集
# 2015      穹顶之下   51113             纪录片  2015-02-28 00:00:00  104  9.2  中国大陆
# 1982        茶馆   10678           剧情/历史  1905-06-04 00:00:00  118  9.2    美国
# 1988       山水情   10781           动画/短片  1905-06-10 00:00:00   19  9.2    美国
# ...        ...     ...             ...                  ...  ...  ...   ...
# 1986  T省的八四、八五     380              剧情  1905-06-08 00:00:00   94  8.7    美国
# 1986   失踪的女中学生     101              儿童  1905-06-08 00:00:00  102  7.4    美国
# 1986     血战台儿庄    2908              战争  1905-06-08 00:00:00  120  8.1    美国
# 1986      血溅画屏      95  剧情/悬疑/犯罪/武侠/古装  1905-06-08 00:00:00   91  7.1    美国
# 1986    魔窟中的幻想      51        惊悚/恐怖/儿童  1905-06-08 00:00:00   78  8.0    美国
#
# [3791 rows x 7 columns]

# %%
df = df.swaplevel('产地','年代')
df.head()
# Out:
#                名字    投票人数        类型                 上映时间   时长   评分    首映地点
# 年代   产地
# 1994 美国    肖申克的救赎  692795     剧情/犯罪  1994-09-10 00:00:00  142  9.6  多伦多电影节
# 1957 美国      控方证人   42995  剧情/悬疑/犯罪  1957-12-17 00:00:00  116  9.5      美国
# 1997 意大利    美丽人生   327855  剧情/喜剧/爱情  1997-12-20 00:00:00  116  9.5     意大利
# 1994 美国      阿甘正传  580897     剧情/爱情  1994-06-23 00:00:00  142  9.4   洛杉矶首映
# 1993 中国大陆    霸王别姬  478523  剧情/爱情/同性  1993-01-01 00:00:00  171  9.4      香港

# %%
df = df.reset_index()
df.head()
# Out:
#      年代    产地      名字    投票人数        类型                 上映时间   时长   评分    首映地点
# 0  1994    美国  肖申克的救赎  692795     剧情/犯罪  1994-09-10 00:00:00  142  9.6  多伦多电影节
# 1  1957    美国    控方证人   42995  剧情/悬疑/犯罪  1957-12-17 00:00:00  116  9.5      美国
# 2  1997   意大利   美丽人生   327855  剧情/喜剧/爱情  1997-12-20 00:00:00  116  9.5     意大利
# 3  1994    美国    阿甘正传  580897     剧情/爱情  1994-06-23 00:00:00  142  9.4   洛杉矶首映
# 4  1993  中国大陆    霸王别姬  478523  剧情/爱情/同性  1993-01-01 00:00:00  171  9.4      香港

# %%
group = df.groupby(df['产地'])
group

# %%
group.mean()
# Out:
# C:\Users\xiaoqian\AppData\Local\Temp\ipykernel_18344\3928442431.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   group.mean()
#                年代          投票人数        评分
# 产地
# 中国台湾  1999.009709   8474.864078  7.066667
# 中国大陆  2004.582432  10915.587708  6.062991
# 中国香港  1991.088865   8141.709870  6.473551
# 丹麦    1999.091371   2003.781726  7.246701
# 俄罗斯   1984.892857   1021.180672  7.557143
# 其他    1998.721721   1619.144450  7.226713
# 加拿大   2002.520451   1921.834979  6.727221
# 印度    2006.039326   3219.587079  6.864888
# 墨西哥   1992.786325   1191.982906  7.085470
# 巴西    1999.888889   3606.333333  7.232323
# 德国    1996.053869   2624.736533  7.187365
# 意大利   1985.599190   3374.955466  7.183131
# 日本    2007.312163   3591.308169  7.192910
# 比利时   1999.503650   1244.153285  7.197080
# ...

# %%
df['评分'].groupby(df['年代']).mean()
# Out:
# 年代
# 1888     7.950000
# 1890     4.800000
# 1892     7.500000
# 1894     6.633333
# 1895     7.575000
#            ...
# 2013     6.375974
# 2014     6.249384
# 2015     6.121925
# 2016     5.834524
# 39180    8.900000
# Name: 评分, Length: 127, dtype: float64

# %%
aa = df['评分'].groupby([df['产地'],df['年代']])
means = aa.mean()
means
# Out:
# 产地    年代
# 中国台湾  1963    6.400000
#       1965    6.800000
#       1966    7.900000
#       1967    8.000000
#       1968    7.400000
#                 ...
# 韩国    2012    6.035238
#       2013    6.062037
#       2014    5.650833
#       2015    5.423853
#       2016    5.730000
# Name: 评分, Length: 1578, dtype: float64

# %%
df['评分等级'] = pd.cut(df['评分'],[0,3,5,7,9,10],labels=['E','D','C','B','A'])
df
# Out:
#          年代    产地                                                 名字    投票人数  \
# 0      1994    美国                                             肖申克的救赎  692795
# 1      1957    美国                                               控方证人   42995
# 2      1997   意大利                                              美丽人生   327855
# 3      1994    美国                                               阿甘正传  580897
# 4      1993  中国大陆                                               霸王别姬  478523
# ...     ...   ...                                                ...     ...
# 38162  1983    法国                                              神学院 S      46
# 38163  1935    美国                                              1935年      57
# 38164  1986  中国大陆                                               血溅画屏      95
# 38165  1986  中国大陆                                             魔窟中的幻想      51
# 38166  1977   俄罗斯  列宁格勒围困之星火战役 Блокада: Фильм 2: Ленинградский ме...      32
#
# ...

# %%
plt.figure()
sns.countplot(y='评分等级',data=df)
# Out:
# <Axes: xlabel='count', ylabel='评分等级'>
# C:\Users\xiaoqian\anaconda3\Lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 35780 (\N{CJK UNIFIED IDEOGRAPH-8BC4}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\xiaoqian\anaconda3\Lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\xiaoqian\anaconda3\Lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 31561 (\N{CJK UNIFIED IDEOGRAPH-7B49}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\xiaoqian\anaconda3\Lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 32423 (\N{CJK UNIFIED IDEOGRAPH-7EA7}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\xiaoqian\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 35780 (\N{CJK UNIFIED IDEOGRAPH-8BC4}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
bins = np.percentile(df['投票人数'],[0,20,40,60,80,100])

# %%
df['热门程度'] = pd.cut(df['投票人数'],bins,labels=['E','D','C','B','A'])
df
# Out:
#          年代    产地                                                 名字    投票人数  \
# 0      1994    美国                                             肖申克的救赎  692795
# 1      1957    美国                                               控方证人   42995
# 2      1997   意大利                                              美丽人生   327855
# 3      1994    美国                                               阿甘正传  580897
# 4      1993  中国大陆                                               霸王别姬  478523
# ...     ...   ...                                                ...     ...
# 38162  1983    法国                                              神学院 S      46
# 38163  1935    美国                                              1935年      57
# 38164  1986  中国大陆                                               血溅画屏      95
# 38165  1986  中国大陆                                             魔窟中的幻想      51
# 38166  1977   俄罗斯  列宁格勒围困之星火战役 Блокада: Фильм 2: Ленинградский ме...      32
#
# ...

# %%
plt.figure()
sns.countplot(y='热门程度',data=df)
# Out:
# <Axes: xlabel='count', ylabel='热门程度'>
# C:\Users\xiaoqian\anaconda3\Lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 28909 (\N{CJK UNIFIED IDEOGRAPH-70ED}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\xiaoqian\anaconda3\Lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 38376 (\N{CJK UNIFIED IDEOGRAPH-95E8}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\xiaoqian\anaconda3\Lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 31243 (\N{CJK UNIFIED IDEOGRAPH-7A0B}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\xiaoqian\anaconda3\Lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 24230 (\N{CJK UNIFIED IDEOGRAPH-5EA6}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\xiaoqian\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 28909 (\N{CJK UNIFIED IDEOGRAPH-70ED}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
df_usa = df[df['产地'] == '美国']
df_china = df[df['产地'] == '中国大陆']
df_usa
# Out:
#          年代  产地      名字    投票人数           类型                 上映时间   时长   评分  \
# 0      1994  美国  肖申克的救赎  692795        剧情/犯罪  1994-09-10 00:00:00  142  9.6
# 1      1957  美国    控方证人   42995     剧情/悬疑/犯罪  1957-12-17 00:00:00  116  9.5
# 3      1994  美国    阿甘正传  580897        剧情/爱情  1994-06-23 00:00:00  142  9.4
# 5      2012  美国  泰坦尼克号   157074     剧情/爱情/灾难  2012-04-10 00:00:00  194  9.4
# 6      1993  美国  辛德勒的名单  306904     剧情/历史/战争  1993-11-30 00:00:00  195  9.4
# ...     ...  ..     ...     ...          ...                  ...  ...  ...
# 38153  1987  美国   跷家的一夜      82  喜剧/动作/惊悚/冒险  1987-07-01 00:00:00  102  7.8
# 38155  1987  美国   零下的激情     199     剧情/爱情/犯罪  1987-11-06 00:00:00   98  7.4
# 38157  1986  美国    离别秋波     240     剧情/爱情/音乐  1986-02-19 00:00:00   90  8.2
# 38161  1986  美国    极乐森林      45          纪录片  1986-09-14 00:00:00   90  8.1
# 38163  1935  美国   1935年      57        喜剧/歌舞  1935-03-15 00:00:00   98  7.6
#
#          首映地点 评分等级 热门程度
# 0      多伦多电影节    A    A
# ...

# %%
df_china.head()
# Out:
#       年代    产地    名字    投票人数        类型                 上映时间   时长   评分  首映地点  \
# 4   1993  中国大陆  霸王别姬  478523  剧情/爱情/同性  1993-01-01 00:00:00  171  9.4    香港
# 21  1961  中国大陆  大闹天宫   74881     动画/奇幻  1905-05-14 00:00:00  114  9.2    上集
# 29  2015  中国大陆  穹顶之下   51113       纪录片  2015-02-28 00:00:00  104  9.2  中国大陆
# 38  1982  中国大陆    茶馆   10678     剧情/历史  1905-06-04 00:00:00  118  9.2    美国
# 45  1988  中国大陆   山水情   10781     动画/短片  1905-06-10 00:00:00   19  9.2    美国
#
#    评分等级 热门程度
# 4     A    A
# 21    A    A
# 29    A    A
# 38    A    A
# 45    A    A

# %%
df_china.append(df_usa)
# Out:
# C:\Users\xiaoqian\AppData\Local\Temp\ipykernel_18344\3975142089.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_china.append(df_usa)
#          年代    产地     名字    投票人数           类型                 上映时间   时长   评分  \
# 4      1993  中国大陆   霸王别姬  478523     剧情/爱情/同性  1993-01-01 00:00:00  171  9.4
# 21     1961  中国大陆   大闹天宫   74881        动画/奇幻  1905-05-14 00:00:00  114  9.2
# 29     2015  中国大陆   穹顶之下   51113          纪录片  2015-02-28 00:00:00  104  9.2
# 38     1982  中国大陆     茶馆   10678        剧情/历史  1905-06-04 00:00:00  118  9.2
# 45     1988  中国大陆    山水情   10781        动画/短片  1905-06-10 00:00:00   19  9.2
# ...     ...   ...    ...     ...          ...                  ...  ...  ...
# 38153  1987    美国  跷家的一夜      82  喜剧/动作/惊悚/冒险  1987-07-01 00:00:00  102  7.8
# 38155  1987    美国  零下的激情     199     剧情/爱情/犯罪  1987-11-06 00:00:00   98  7.4
# ...

# %%
df1 = df.loc[:5]
df1
# Out:
#      年代    产地      名字    投票人数        类型                 上映时间   时长   评分  \
# 0  1994    美国  肖申克的救赎  692795     剧情/犯罪  1994-09-10 00:00:00  142  9.6
# 1  1957    美国    控方证人   42995  剧情/悬疑/犯罪  1957-12-17 00:00:00  116  9.5
# 2  1997   意大利   美丽人生   327855  剧情/喜剧/爱情  1997-12-20 00:00:00  116  9.5
# 3  1994    美国    阿甘正传  580897     剧情/爱情  1994-06-23 00:00:00  142  9.4
# 4  1993  中国大陆    霸王别姬  478523  剧情/爱情/同性  1993-01-01 00:00:00  171  9.4
# 5  2012    美国  泰坦尼克号   157074  剧情/爱情/灾难  2012-04-10 00:00:00  194  9.4
#
#      首映地点 评分等级 热门程度
# 0  多伦多电影节    A    A
# 1      美国    A    A
# 2     意大利    A    A
# 3   洛杉矶首映    A    A
# 4      香港    A    A
# 5    中国大陆    A    A

# %%
df2 = df.loc[:5][['名字','产地']]
df2['票房'] = [1235648,13548979,153486,534684,2318864,52165498]
df2 = df2.sample(frac=1)
df2.index = range(len(df2))
df2
# Out:
#        名字    产地        票房
# 0    阿甘正传    美国    534684
# 1   美丽人生    意大利    153486
# 2  肖申克的救赎    美国   1235648
# 3  泰坦尼克号     美国  52165498
# 4    控方证人    美国  13548979
# 5    霸王别姬  中国大陆   2318864

# %%
pd.merge(df1,df2,how='inner',on='名字',)
# Out:
#      年代  产地_x      名字    投票人数        类型                 上映时间   时长   评分  \
# 0  1994    美国  肖申克的救赎  692795     剧情/犯罪  1994-09-10 00:00:00  142  9.6
# 1  1957    美国    控方证人   42995  剧情/悬疑/犯罪  1957-12-17 00:00:00  116  9.5
# 2  1997   意大利   美丽人生   327855  剧情/喜剧/爱情  1997-12-20 00:00:00  116  9.5
# 3  1994    美国    阿甘正传  580897     剧情/爱情  1994-06-23 00:00:00  142  9.4
# 4  1993  中国大陆    霸王别姬  478523  剧情/爱情/同性  1993-01-01 00:00:00  171  9.4
# 5  2012    美国  泰坦尼克号   157074  剧情/爱情/灾难  2012-04-10 00:00:00  194  9.4
#
#      首映地点 评分等级 热门程度  产地_y        票房
# 0  多伦多电影节    A    A    美国   1235648
# 1      美国    A    A    美国  13548979
# 2     意大利    A    A   意大利    153486
# 3   洛杉矶首映    A    A    美国    534684
# 4      香港    A    A  中国大陆   2318864
# 5    中国大陆    A    A    美国  52165498
